# %%
import pandas as pd
from geopy.geocoders import Photon
from geopy.geocoders import Nominatim
from unidecode import unidecode
import numpy as np

from shapely.geometry import Point, Polygon
import geopandas as gpd

import matplotlib.pyplot as plt

# %%
#risk2023_filtrado.to_file("C:\\Users\\puria\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\Metodo_1\\areas\\municipiosrisk.shp")
# Out:
# C:\Users\puria\AppData\Local\Temp\ipykernel_9744\3530369648.py:1: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   risk2023_filtrado.to_file("C:\\Users\\puria\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\Metodo_1\\areas\\municipiosrisk.shp")

# %%
risk2023 = gpd.read_file("C:\\Users\\puria\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\Metodo_1\\areas\\municipios\\municipiosshp.shp")

# %%
# Suponiendo que el dataframe es 'risk2023'
# df = pd.read_csv('path_to_your_csv_file.csv')  # Si no está cargado aún

# Función para eliminar acentos de un valor
def quitar_acentos(val):
    if isinstance(val, str):
        return unidecode(val)
    return val

# Aplicar la función a todo el dataframe
risk2023 = risk2023.applymap(quitar_acentos)
# Out:
# C:\Users\puria\AppData\Local\Temp\ipykernel_9744\4022403037.py:15: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   risk2023 = risk2023.applymap(quitar_acentos)

# %%
# Normalizar la columna 'violencia' en una escala de 1 a 100
min_val = risk2023['violencia'].min()
max_val = risk2023['violencia'].max()
risk2023['vio_muj'] = (risk2023['violencia'] - min_val) / (max_val - min_val) * 99 + 1

# Filtrar y reorganizar las columnas
columnas_deseadas = [
    'municipio_entidad', 'geometry', 'cvemunic', 'nomedo', 'nommun',
    'area', 'corrupcion', 'crimenorg', 'violencia', 'vio_muj'
]
risk2023_filtrado = risk2023[columnas_deseadas]

# Mostrar las primeras filas del dataframe para verificar los cambios
print(risk2023_filtrado.head())
# Out:
#                 municipio_entidad  \
# 0  Aguascalientes, Aguascalientes
# 1        Asientos, Aguascalientes
# 2        Calvillo, Aguascalientes
# 3           Cosio, Aguascalientes
# 4        El Llano, Aguascalientes
#
#                                             geometry  cvemunic  \
# 0  POLYGON ((-102.14207 22.07321, -102.12842 22.0...      1001
# 1  POLYGON ((-102.12322 22.28697, -102.11973 22.2...      1002
# 2  POLYGON ((-102.80641 21.99334, -102.80511 21.9...      1003
# 3  POLYGON ((-102.29781 22.45899, -102.29616 22.4...      1004
# 4  POLYGON ((-102.09788 22.02335, -102.08893 22.0...      1010
#
#            nomedo          nommun         area  corrupcion  crimenorg  \
# 0  Aguascalientes  Aguascalientes  1168.762384       474.0     1462.0
# 1  Aguascalientes        Asientos   547.762077         4.0      108.0
# 2  Aguascalientes        Calvillo   931.300088         9.0       54.0
# 3  Aguascalientes           Cosio   128.907513         1.0       31.0
# 4  Aguascalientes        El Llano   500.861359         7.0       14.0
#
#    violencia    vio_muj
# 0     1011.0  36.008395
# 1       28.0   1.969570
# 2       27.0   1.934942
# 3        8.0   1.277020
# 4        8.0   1.277020

# %% [markdown]
# ## Distribucion Institucional

# %%
risk2023_filtrado
# Out:
#                      municipio_entidad  \
# 0       Aguascalientes, Aguascalientes
# 1             Asientos, Aguascalientes
# 2             Calvillo, Aguascalientes
# 3                Cosio, Aguascalientes
# 4             El Llano, Aguascalientes
# ...                                ...
# 2475  Villa Gonzalez Ortega, Zacatecas
# 2476          Villa Hidalgo, Zacatecas
# 2477           Villa de Cos, Zacatecas
# 2478             Villanueva, Zacatecas
# 2479              Zacatecas, Zacatecas
#
#                                                geometry  cvemunic  \
# 0     POLYGON ((-102.14207 22.07321, -102.12842 22.0...      1001
# 1     POLYGON ((-102.12322 22.28697, -102.11973 22.2...      1002
# 2     POLYGON ((-102.80641 21.99334, -102.80511 21.9...      1003
# 3     POLYGON ((-102.29781 22.45899, -102.29616 22.4...      1004
# 4     POLYGON ((-102.09788 22.02335, -102.08893 22.0...      1010
# ...                                                 ...       ...
# 2475  POLYGON ((-101.94625 22.64974, -101.94875 22.6...     32053
# 2476  POLYGON ((-101.65688 22.50250, -101.65540 22.4...     32054
# 2477  POLYGON ((-102.72540 23.78805, -102.72054 23.7...     32051
# 2478  POLYGON ((-102.78672 22.67556, -102.77979 22.6...     32055
# 2479  POLYGON ((-102.84044 22.83587, -102.83242 22.8...     32056
#
#               nomedo                 nommun         area  corrupcion  \
# 0     Aguascalientes         Aguascalientes  1168.762384       474.0
# 1     Aguascalientes               Asientos   547.762077         4.0
# 2     Aguascalientes               Calvillo   931.300088         9.0
# 3     Aguascalientes                  Cosio   128.907513         1.0
# 4     Aguascalientes               El Llano   500.861359         7.0
# ...              ...                    ...          ...         ...
# 2475       Zacatecas  Villa Gonzalez Ortega   417.529939         0.0
# 2476       Zacatecas          Villa Hidalgo   355.528477         1.0
# 2477       Zacatecas           Villa de Cos  6405.541210         2.0
# 2478       Zacatecas             Villanueva  2158.696446         9.0
# 2479       Zacatecas              Zacatecas   444.547742        90.0
#
#       crimenorg  violencia    vio_muj
# 0        1462.0     1011.0  36.008395
# 1         108.0       28.0   1.969570
# 2          54.0       27.0   1.934942
# 3          31.0        8.0   1.277020
# 4          14.0        8.0   1.277020
# ...         ...        ...        ...
# 2475        1.0        4.0   1.138510
# 2476        1.0        1.0   1.034627
# 2477        2.0       13.0   1.450157
# 2478        9.0       15.0   1.519412
# 2479       71.0      264.0  10.141658
#
# [2480 rows x 10 columns]

# %% [markdown]
# ### Normalizar todos los stats

# %% [markdown]
# ## Stat 1: Violencia e Inseguridad Mujeres, Familias y Ninos.
#
# From databse del secretariado ejectuvido del sistema nacional de seguridad publica.
# es el numero de eventos en 2023, por division municipal de: 'Feminicidio','Tráfico de menores','La libertad y la seguridad sexual'; Acoso Sexucal, Abuso Sexual, Hostigamiento Sexual, Violacion Simple, Violacion Equiparada. Y 'La sociedad'; ,;, .

# %%
# Normalizar la columna 'Violencia' en una escala de 1 a 100
min_val = risk2023['Violencia'].min()
max_val = risk2023['Violencia'].max()

risk2023['Violencia_normalizada'] = (risk2023['Violencia'] - min_val) / (max_val - min_val) * 99 + 1

# %%
# Cambiar el formato de la columna 'Clave_Ent' a dos dígitos
crime2023['Clave_Ent'] = crime2023['Clave_Ent'].astype(str).apply(lambda x: x.zfill(2))

# Mostrar el DataFrame actualizado para verificar los cambios
print(crime2023['Clave_Ent'])
# Out:
# 0         01
# 1         01
# 2         01
# 3         01
# 4         01
#           ..
# 243329    32
# 243330    32
# 243331    32
# 243332    32
# 243333    32
# Name: Clave_Ent, Length: 243334, dtype: object

# %%
mx_mun = gpd.read_file('/Users/pablouriarte/Mapa_Migracion_Irregular_Mexico_Fresh/1. Mapas/2. arcgis(general)/maps_boundaries/Municipalities/mapa_mexico_mun/Division_Municipal_Mexico_2010.shp').set_index('CLAVE').to_crs(epsg=4485)

# %%
# Crear la columna 'Cve. Municipio' concatenando 'CVE_EDO' y 'CVE_MUNI'
mx_mun['Cve. Municipio'] = mx_mun['CVE_EDO'].astype(str).str.zfill(2) + mx_mun['CVE_MUNI'].astype(str).str.zfill(3)

# Convertir la nueva columna a tipo entero para eliminar cualquier cero inicial no deseado
mx_mun['Cve. Municipio'] = mx_mun['Cve. Municipio'].astype(int)

# %%
mx_mun.info
# Out:
# <bound method DataFrame.info of                      NOM_MUN          NOMEDO CVE_EDO CVE_MUNI         Area  \
# CLAVE
# 01001         Aguascalientes  Aguascalientes      01      001  1168.762384
# 01002               Asientos  Aguascalientes      01      002   547.762077
# 01003               Calvillo  Aguascalientes      01      003   931.300088
# 01004                  Cosio  Aguascalientes      01      004   128.907513
# 01005            Jesus Maria  Aguascalientes      01      005   499.207990
# ...                      ...             ...     ...      ...          ...
# 32053  Villa Gonzalez Ortega       Zacatecas      32      053   417.529939
# 32054          Villa Hidalgo       Zacatecas      32      054   355.528477
# 32055             Villanueva       Zacatecas      32      055  2158.696446
# 32056              Zacatecas       Zacatecas      32      056   444.547742
# 32057               Trancoso       Zacatecas      32      057   215.239163
#
#                                                 geometry  Cve. Municipio
# CLAVE
# 01001  POLYGON ((1416489.577 2467700.472, 1417908.226...            1001
# 01002  POLYGON ((1417043.958 2491681.240, 1417408.488...            1002
# 01003  POLYGON ((1347882.273 2454901.097, 1348002.307...            1003
# 01004  POLYGON ((1397788.297 2509816.078, 1398009.089...            1004
# 01005  POLYGON ((1388272.165 2462097.533, 1389832.232...            1005
# ...                                                  ...             ...
# 32053  POLYGON ((1432967.088 2533295.874, 1432739.332...           32053
# 32054  POLYGON ((1464010.774 2518715.060, 1464186.335...           32054
# 32055  POLYGON ((1345756.044 2531084.706, 1346503.579...           32055
# 32056  POLYGON ((1339206.596 2548649.944, 1340025.280...           32056
# 32057  POLYGON ((1400816.550 2541592.398, 1400764.458...           32057
#
# [2480 rows x 7 columns]>

# %%
crime2023.info
# Out:
# <bound method DataFrame.info of          Año Clave_Ent         Entidad  Cve. Municipio              Municipio  \
# 0       2023        01  Aguascalientes            1001         Aguascalientes
# 1       2023        01  Aguascalientes            1001         Aguascalientes
# 2       2023        01  Aguascalientes            1001         Aguascalientes
# 3       2023        01  Aguascalientes            1001         Aguascalientes
# 4       2023        01  Aguascalientes            1001         Aguascalientes
# ...      ...       ...             ...             ...                    ...
# 243329  2023        32       Zacatecas           32058  Santa María de la Paz
# 243330  2023        32       Zacatecas           32058  Santa María de la Paz
# 243331  2023        32       Zacatecas           32058  Santa María de la Paz
# 243332  2023        32       Zacatecas           32058  Santa María de la Paz
# 243333  2023        32       Zacatecas           32058  Santa María de la Paz
#
#                                    Bien jurídico afectado  \
# 0                        La vida y la Integridad corporal
# 1                        La vida y la Integridad corporal
# 2                        La vida y la Integridad corporal
# 3                        La vida y la Integridad corporal
# 4                        La vida y la Integridad corporal
# ...                                                   ...
# 243329  Otros bienes jurídicos afectados (del fuero co...
# 243330  Otros bienes jurídicos afectados (del fuero co...
# 243331  Otros bienes jurídicos afectados (del fuero co...
# 243332  Otros bienes jurídicos afectados (del fuero co...
# 243333  Otros bienes jurídicos afectados (del fuero co...
#
#                                    Tipo de delito  \
# 0                                       Homicidio
# 1                                       Homicidio
# 2                                       Homicidio
# 3                                       Homicidio
# 4                                       Homicidio
# ...                                           ...
# 243329                              Falsificación
# 243330                   Contra el medio ambiente
# 243331  Delitos cometidos por servidores públicos
# 243332                                Electorales
# 243333              Otros delitos del Fuero Común
#
#                                 Subtipo de delito  \
# 0                                Homicidio doloso
# 1                                Homicidio doloso
# 2                                Homicidio doloso
# 3                                Homicidio doloso
# 4                               Homicidio culposo
# ...                                           ...
# 243329                              Falsificación
# 243330                   Contra el medio ambiente
# 243331  Delitos cometidos por servidores públicos
# 243332                                Electorales
# 243333              Otros delitos del Fuero Común
#
#                                         Modalidad  Enero  ...  Marzo  Abril  \
# 0                               Con arma de fuego      1  ...      2      1
# 1                                 Con arma blanca      2  ...      0      1
# 2                               Con otro elemento      1  ...      1      0
# 3                                 No especificado      0  ...      0      0
# 4                               Con arma de fuego      0  ...      0      0
# ...                                           ...    ...  ...    ...    ...
# 243329                              Falsificación      0  ...      0      0
# 243330                   Contra el medio ambiente      0  ...      0      0
# 243331  Delitos cometidos por servidores públicos      0  ...      0      0
# 243332                                Electorales      0  ...      0      0
# 243333              Otros delitos del Fuero Común      0  ...      1      0
#
#         Mayo  Junio  Julio  Agosto  Septiembre  Octubre  Noviembre  Diciembre
# 0          1      1      1       4           1        1          0          2
# 1          0      2      0       3           1        0          3          0
# 2          0      3      0       0           1        1          2          1
# 3          0      0      0       0           0        0          0          0
# 4          0      0      0       0           0        0          0          0
# ...      ...    ...    ...     ...         ...      ...        ...        ...
# 243329     0      0      0       0           0        0          0          0
# 243330     0      0      0       0           0        0          0          0
# 243331     0      0      0       0           0        0          0          0
# 243332     0      0      0       0           0        0          0          0
# 243333     0      0      0       1           0        0          0          0
#
# [243334 rows x 21 columns]>

# %%
# Convertir 'Cve. Municipio' a entero
#mx_mun['Cve. Municipio'] = mx_mun['Cve. Municipio'].astype(int)

# Ordenar el DataFrame en forma ascendente por 'Cve. Municipio' como entero
mx_mun = mx_mun.sort_values(by='Cve. Municipio', ascending=True)

# %%
mx_mun
# Out:
#                      NOM_MUN          NOMEDO CVE_EDO CVE_MUNI         Area  \
# CLAVE
# 01001         Aguascalientes  Aguascalientes      01      001  1168.762384
# 01002               Asientos  Aguascalientes      01      002   547.762077
# 01003               Calvillo  Aguascalientes      01      003   931.300088
# 01004                  Cosio  Aguascalientes      01      004   128.907513
# 01005            Jesus Maria  Aguascalientes      01      005   499.207990
# ...                      ...             ...     ...      ...          ...
# 32053  Villa Gonzalez Ortega       Zacatecas      32      053   417.529939
# 32054          Villa Hidalgo       Zacatecas      32      054   355.528477
# 32055             Villanueva       Zacatecas      32      055  2158.696446
# 32056              Zacatecas       Zacatecas      32      056   444.547742
# 32057               Trancoso       Zacatecas      32      057   215.239163
#
#                                                 geometry  Cve. Municipio
# CLAVE
# 01001  POLYGON ((1416489.577 2467700.472, 1417908.226...            1001
# 01002  POLYGON ((1417043.958 2491681.240, 1417408.488...            1002
# 01003  POLYGON ((1347882.273 2454901.097, 1348002.307...            1003
# 01004  POLYGON ((1397788.297 2509816.078, 1398009.089...            1004
# 01005  POLYGON ((1388272.165 2462097.533, 1389832.232...            1005
# ...                                                  ...             ...
# 32053  POLYGON ((1432967.088 2533295.874, 1432739.332...           32053
# 32054  POLYGON ((1464010.774 2518715.060, 1464186.335...           32054
# 32055  POLYGON ((1345756.044 2531084.706, 1346503.579...           32055
# 32056  POLYGON ((1339206.596 2548649.944, 1340025.280...           32056
# 32057  POLYGON ((1400816.550 2541592.398, 1400764.458...           32057
#
# [2480 rows x 7 columns]

# %%
import pandas as pd

# Assuming 'crime2023' is your DataFrame
# Display unique values in the 'Tipo de delito' column
unique_types = crime2023['Tipo de delito'].unique()
print("Unique values in 'Tipo de delito':")
print(unique_types)

# Display unique values in the 'Bien jurídico afectado' column
unique_subtypes = crime2023['Bien jurídico afectado'].unique()
print("\nUnique values in 'Bien jurídico afectado':")
print(unique_subtypes)
# Out:
# Unique values in 'Tipo de delito':
# ['Homicidio' 'Lesiones' 'Feminicidio' 'Aborto'
#  'Otros delitos que atentan contra la vida y la integridad corporal'
#  'Secuestro' 'Tráfico de menores' 'Rapto'
#  'Otros delitos que atentan contra la libertad personal' 'Abuso sexual'
#  'Acoso sexual' 'Hostigamiento sexual' 'Violación simple'
#  'Violación equiparada' 'Incesto'
#  'Otros delitos que atentan contra la libertad y la seguridad sexual'
#  'Robo' 'Fraude' 'Abuso de confianza' 'Extorsión' 'Daño a la propiedad'
#  'Despojo' 'Otros delitos contra el patrimonio' 'Violencia familiar'
#  'Violencia de género en todas sus modalidades distinta a la violencia familiar'
#  'Incumplimiento de obligaciones de asistencia familiar'
#  'Otros delitos contra la familia' 'Corrupción de menores'
#  'Trata de personas' 'Otros delitos contra la sociedad' 'Narcomenudeo'
#  'Amenazas' 'Allanamiento de morada' 'Evasión de presos' 'Falsedad'
#  'Falsificación' 'Contra el medio ambiente'
#  'Delitos cometidos por servidores públicos' 'Electorales'
#  'Otros delitos del Fuero Común']
#
# Unique values in 'Bien jurídico afectado':
# ['La vida y la Integridad corporal' 'Libertad personal'
#  'La libertad y la seguridad sexual' 'El patrimonio' 'La familia'
#  'La sociedad' 'Otros bienes jurídicos afectados (del fuero común)']

# %%
# Filtramos primero por las categorías principales de 'Bien jurídico afectado'
categorias_deseadas = [
    "La libertad y la seguridad sexual",
    "La sociedad",
    "La vida y la Integridad corporal",
    "Libertad personal",
    "Otros bienes jurídicos afectados (del fuero común)"
]

filtered_crime2023 = crime2023[crime2023['Bien jurídico afectado'].isin(categorias_deseadas)]

# Ahora definimos las subcategorías específicas para filtrar en 'Tipo de delito'
# según corresponda a la categoría principal
subcategorias_filtro = {
    "La vida y la Integridad corporal": ["Feminicidio"],
    "Libertad personal": ["Tráfico de menores"],
    "Otros bienes jurídicos afectados (del fuero común)": ["Narcomenudeo", "Delitos cometidos por servidores públicos"]
}

# Aplicar filtro adicional basado en subcategorías específicas
def filtro_adicional(row):
    if row['Bien jurídico afectado'] in subcategorias_filtro:
        # Si hay subcategorías específicas, filtrar por ellas
        return row['Tipo de delito'] in subcategorias_filtro[row['Bien jurídico afectado']]
    else:
        # Si no hay subcategorías específicas, mantener la fila
        return True

# Aplicamos el filtro adicional
filtered_crime2023 = filtered_crime2023[filtered_crime2023.apply(filtro_adicional, axis=1)]

# %%
# Eliminar la columna "Modalidad"
filtered_crime2023 = filtered_crime2023.drop('Modalidad', axis=1)

# Lista de nombres de las columnas de los meses
meses = [
    "Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio", 
    "Julio", "Agosto", "Septiembre", "Octubre", "Noviembre", "Diciembre"
]

# Sumar las columnas de los meses para cada fila
filtered_crime2023['Total delitos'] = filtered_crime2023[meses].sum(axis=1)

# Eliminar las columnas individuales de los meses si ya no se necesitan
filtered_crime2023 = filtered_crime2023.drop(columns=meses)

# %%
filtered_crime2023
# Out:
#          Año Clave_Ent         Entidad  Cve. Municipio              Municipio  \
# 18      2023        01  Aguascalientes            1001         Aguascalientes
# 19      2023        01  Aguascalientes            1001         Aguascalientes
# 20      2023        01  Aguascalientes            1001         Aguascalientes
# 21      2023        01  Aguascalientes            1001         Aguascalientes
# 29      2023        01  Aguascalientes            1001         Aguascalientes
# ...      ...       ...             ...             ...                    ...
# 243321  2023        32       Zacatecas           32058  Santa María de la Paz
# 243322  2023        32       Zacatecas           32058  Santa María de la Paz
# 243323  2023        32       Zacatecas           32058  Santa María de la Paz
# 243324  2023        32       Zacatecas           32058  Santa María de la Paz
# 243331  2023        32       Zacatecas           32058  Santa María de la Paz
#
#                                    Bien jurídico afectado  \
# 18                       La vida y la Integridad corporal
# 19                       La vida y la Integridad corporal
# 20                       La vida y la Integridad corporal
# 21                       La vida y la Integridad corporal
# 29                                      Libertad personal
# ...                                                   ...
# 243321                                        La sociedad
# 243322                                        La sociedad
# 243323                                        La sociedad
# 243324  Otros bienes jurídicos afectados (del fuero co...
# 243331  Otros bienes jurídicos afectados (del fuero co...
#
#                                    Tipo de delito  \
# 18                                    Feminicidio
# 19                                    Feminicidio
# 20                                    Feminicidio
# 21                                    Feminicidio
# 29                             Tráfico de menores
# ...                                           ...
# 243321                      Corrupción de menores
# 243322                          Trata de personas
# 243323           Otros delitos contra la sociedad
# 243324                               Narcomenudeo
# 243331  Delitos cometidos por servidores públicos
#
#                                 Subtipo de delito  Total delitos
# 18                                    Feminicidio              0
# 19                                    Feminicidio              0
# 20                                    Feminicidio              0
# 21                                    Feminicidio              0
# 29                             Tráfico de menores              0
# ...                                           ...            ...
# 243321                      Corrupción de menores              0
# 243322                          Trata de personas              0
# 243323           Otros delitos contra la sociedad              0
# 243324                               Narcomenudeo              0
# 243331  Delitos cometidos por servidores públicos              0
#
# [42211 rows x 9 columns]

# %%
def etiquetar(row):
    if row['Bien jurídico afectado'] == 'La vida y la Integridad corporal' and row['Tipo de delito'] == 'Feminicidio':
        return 'Violencia Mujeres, Familias y Niños'
    elif row['Bien jurídico afectado'] == 'Libertad personal' and row['Tipo de delito'] == 'Tráfico de menores':
        return 'Violencia Mujeres, Familias y Niños'
    elif row['Bien jurídico afectado'] == 'La libertad y la seguridad sexual':
        return 'Violencia Mujeres, Familias y Niños'
    elif row['Bien jurídico afectado'] == 'La sociedad':
        return 'Violencia Mujeres, Familias y Niños'
    
    elif row['Bien jurídico afectado'] == 'Otros bienes jurídicos afectados (del fuero común)' and row['Tipo de delito'] == 'Narcomenudeo':
        return 'Crimen Organizado'
    
    elif row['Bien jurídico afectado'] == 'Otros bienes jurídicos afectados (del fuero común)' and row['Tipo de delito'] == 'Delitos cometidos por servidores públicos':
        return 'Corrupción Institucional'
    else:
        return 'Otra categoría'  # o puedes elegir un valor predeterminado más específico

# Aplicar la función para crear la nueva columna de etiquetas
filtered_crime2023['Etiqueta'] = filtered_crime2023.apply(etiquetar, axis=1)

# %%
# Eliminar las columnas que no se necesitan
columns_to_drop = ['Bien jurídico afectado', 'Tipo de delito', 'Subtipo de delito']
df_reduced = filtered_crime2023.drop(columns=columns_to_drop)

# Agrupar por 'Cve. Municipio' y 'Etiqueta', y sumar los valores de 'Total delitos'
df_aggregated = df_reduced.groupby(['Entidad','Municipio','Cve. Municipio', 'Etiqueta']).agg({'Total delitos': 'sum'}).reset_index()

# %%
df_aggregated.info
# Out:
# <bound method DataFrame.info of              Entidad       Municipio  Cve. Municipio  \
# 0     Aguascalientes  Aguascalientes            1001
# 1     Aguascalientes  Aguascalientes            1001
# 2     Aguascalientes  Aguascalientes            1001
# 3     Aguascalientes        Asientos            1002
# 4     Aguascalientes        Asientos            1002
# ...              ...             ...             ...
# 7444       Zacatecas      Villanueva           32055
# 7445       Zacatecas      Villanueva           32055
# 7446       Zacatecas       Zacatecas           32056
# 7447       Zacatecas       Zacatecas           32056
# 7448       Zacatecas       Zacatecas           32056
#
#                                  Etiqueta  Total delitos
# 0                Corrupción Institucional            474
# 1                       Crimen Organizado           1462
# 2     Violencia Mujeres, Familias y Niños           1011
# 3                Corrupción Institucional              4
# 4                       Crimen Organizado            108
# ...                                   ...            ...
# 7444                    Crimen Organizado              9
# 7445  Violencia Mujeres, Familias y Niños             15
# 7446             Corrupción Institucional             90
# 7447                    Crimen Organizado             71
# 7448  Violencia Mujeres, Familias y Niños            264
#
# [7449 rows x 5 columns]>

# %%
# Seleccionar las columnas necesarias de 'mx_mun'
mx_mun_reduced = mx_mun[['NOMEDO','Cve. Municipio', 'NOM_MUN', 'Area', 'geometry']]

# Convertir 'Cve. Municipio' en ambos DataFrames a tipo int para asegurar una comparación correcta
mx_mun_reduced['Cve. Municipio'] = mx_mun_reduced['Cve. Municipio'].astype(int)
df_aggregated['Cve. Municipio'] = df_aggregated['Cve. Municipio'].astype(int)

# Realizar el merge
df_final = pd.merge(df_aggregated, mx_mun_reduced, on='Cve. Municipio', how='left')
# Out:
# /Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopandas/geodataframe.py:1538: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super().__setitem__(key, value)

# %%
# Resetear el índice del DataFrame para asegurar que no hayan duplicados
df_final = df_final.reset_index(drop=True)

# %%
df_final.info
# Out:
# <bound method DataFrame.info of              Entidad       Municipio  Cve. Municipio  \
# 0     Aguascalientes  Aguascalientes            1001
# 1     Aguascalientes  Aguascalientes            1001
# 2     Aguascalientes  Aguascalientes            1001
# 3     Aguascalientes        Asientos            1002
# 4     Aguascalientes        Asientos            1002
# ...              ...             ...             ...
# 7561       Zacatecas      Villanueva           32055
# 7562       Zacatecas      Villanueva           32055
# 7563       Zacatecas       Zacatecas           32056
# 7564       Zacatecas       Zacatecas           32056
# 7565       Zacatecas       Zacatecas           32056
#
#                                  Etiqueta  Total delitos          NOMEDO  \
# 0                Corrupción Institucional            474  Aguascalientes
# 1                       Crimen Organizado           1462  Aguascalientes
# 2     Violencia Mujeres, Familias y Niños           1011  Aguascalientes
# 3                Corrupción Institucional              4  Aguascalientes
# 4                       Crimen Organizado            108  Aguascalientes
# ...                                   ...            ...             ...
# 7561                    Crimen Organizado              9       Zacatecas
# 7562  Violencia Mujeres, Familias y Niños             15       Zacatecas
# 7563             Corrupción Institucional             90       Zacatecas
# 7564                    Crimen Organizado             71       Zacatecas
# 7565  Violencia Mujeres, Familias y Niños            264       Zacatecas
#
#              NOM_MUN         Area  \
# 0     Aguascalientes  1168.762384
# 1     Aguascalientes  1168.762384
# 2     Aguascalientes  1168.762384
# 3           Asientos   547.762077
# 4           Asientos   547.762077
# ...              ...          ...
# 7561      Villanueva  2158.696446
# 7562      Villanueva  2158.696446
# 7563       Zacatecas   444.547742
# 7564       Zacatecas   444.547742
# 7565       Zacatecas   444.547742
#
#                                                geometry
# 0     POLYGON ((1416489.577 2467700.472, 1417908.226...
# 1     POLYGON ((1416489.577 2467700.472, 1417908.226...
# 2     POLYGON ((1416489.577 2467700.472, 1417908.226...
# 3     POLYGON ((1417043.958 2491681.240, 1417408.488...
# 4     POLYGON ((1417043.958 2491681.240, 1417408.488...
# ...                                                 ...
# 7561  POLYGON ((1345756.044 2531084.706, 1346503.579...
# 7562  POLYGON ((1345756.044 2531084.706, 1346503.579...
# 7563  POLYGON ((1339206.596 2548649.944, 1340025.280...
# 7564  POLYGON ((1339206.596 2548649.944, 1340025.280...
# 7565  POLYGON ((1339206.596 2548649.944, 1340025.280...
#
# [7566 rows x 9 columns]>

# %%
# Intentar de nuevo filtrar para obtener solo las filas donde 'NOM_MUN' es NaN
nan_rows = df_final[df_final['NOM_MUN'].isna()]

# %%
nan_rows
# Out:
#                               Entidad              Municipio  Cve. Municipio  \
# 42                    Baja California             San Felipe            2007
# 43                    Baja California             San Felipe            2007
# 44                    Baja California             San Felipe            2007
# 45                    Baja California            San Quintín            2006
# 46                    Baja California            San Quintín            2006
# ...                               ...                    ...             ...
# 6871  Veracruz de Ignacio de la Llave     Santiago Sochiapan           30212
# 6872  Veracruz de Ignacio de la Llave     Santiago Sochiapan           30212
# 7512                        Zacatecas  Santa María de la Paz           32058
# 7513                        Zacatecas  Santa María de la Paz           32058
# 7514                        Zacatecas  Santa María de la Paz           32058
#
#                                  Etiqueta  Total delitos NOMEDO NOM_MUN  Area  \
# 42               Corrupción Institucional              1    NaN     NaN   NaN
# 43                      Crimen Organizado             22    NaN     NaN   NaN
# 44    Violencia Mujeres, Familias y Niños             35    NaN     NaN   NaN
# 45               Corrupción Institucional             20    NaN     NaN   NaN
# 46                      Crimen Organizado             58    NaN     NaN   NaN
# ...                                   ...            ...    ...     ...   ...
# 6871                    Crimen Organizado              0    NaN     NaN   NaN
# 6872  Violencia Mujeres, Familias y Niños              8    NaN     NaN   NaN
# 7512             Corrupción Institucional              0    NaN     NaN   NaN
# 7513                    Crimen Organizado              0    NaN     NaN   NaN
# 7514  Violencia Mujeres, Familias y Niños              2    NaN     NaN   NaN
#
#      geometry
# 42       None
# 43       None
# 44       None
# 45       None
# 46       None
# ...       ...
# 6871     None
# 6872     None
# 7512     None
# 7513     None
# 7514     None
#
# [126 rows x 9 columns]

# %%
# Eliminar todas las filas que tienen al menos un NaN en cualquier columna
df_final_clean = df_final.dropna()

# %%
print(df_final_clean['geometry'].head())
# Out:
# 0    POLYGON ((1416489.577 2467700.472, 1417908.226...
# 1    POLYGON ((1416489.577 2467700.472, 1417908.226...
# 2    POLYGON ((1416489.577 2467700.472, 1417908.226...
# 3    POLYGON ((1417043.958 2491681.240, 1417408.488...
# 4    POLYGON ((1417043.958 2491681.240, 1417408.488...
# Name: geometry, dtype: geometry

# %%
# Definir la ruta donde deseas guardar el shapefile
shapefile_path = "/Users/pablouriarte/Mapa_Migracion_Irregular_Mexico_Fresh/1. Mapas/1. Mapas/Metodo_1/areas/df_final_shape"

# Guardar el GeoDataFrame como shapefile
gdf.to_file(f"{shapefile_path}.shp")

print("Shapefile guardado con éxito en:", shapefile_path + ".shp")
push"
# Out:
# /var/folders/68/6zkv8z4j4rl6ds90br2rb7ph0000gn/T/ipykernel_7632/3149254785.py:5: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   gdf.to_file(f"{shapefile_path}.shp")
# Shapefile guardado con éxito en: /Users/pablouriarte/Mapa_Migracion_Irregular_Mexico_Fresh/1. Mapas/1. Mapas/Metodo_1/areas/df_final_shape.shp

# %%
# Guardar el DataFrame final en un archivo CSV
#path = "/Users/pablouriarte/Mapa_Migracion_Irregular_Mexico_Fresh/1. Mapas/1. Mapas/Metodo_1/areas/riskzone.csv"
#df_final_clean.to_csv(path, index=False)

# %%
import gzip
import shutil

# Ruta del archivo original
#path_original = "/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/1. Mapas/1. Mapas/Metodo_1/areas/riskzone.csv"
# Ruta del archivo comprimido
path_comprimido = "/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/1. Mapas/1. Mapas/Metodo_1/areas/riskzone.csv.gz"

# Abrir el archivo original y el archivo comprimido
with open(path_original, 'rb') as f_in, gzip.open(path_comprimido, 'wb') as f_out:
    # Copiar el contenido del archivo original al archivo comprimido usando gzip
    shutil.copyfileobj(f_in, f_out)

print("Archivo comprimido con éxito.")

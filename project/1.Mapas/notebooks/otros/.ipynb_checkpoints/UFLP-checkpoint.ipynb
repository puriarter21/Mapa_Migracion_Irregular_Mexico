# %%
import pandas as pd
from geopy.geocoders import Photon
from geopy.geocoders import Nominatim
from unidecode import unidecode
import unidecode
import numpy as np
from shapely.geometry import Point, Polygon
import geopandas as gpd
import seaborn as sns
import geopandas as gpd
from shapely import wkt
import matplotlib.pyplot as plt
import pulp

# %% [markdown]
# # UFLP

# %%
dfvalores = pd.read_csv('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\df_valores_rutas.csv')
inm = pd.read_csv('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\3.datos\\1. distribution_infraestructura\\1. Estaciones INM\\inm_gdp.csv')
sc = pd.read_csv('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\3.datos\\1. distribution_infraestructura\\2. SC Instituciones\\Facility_Directory.csv')
mun_shp = gpd.read_file("C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\areas\\municipiosrisk1.shp")

# %%
mun_shp
# Out:
#                                 nommun cvemun          nomedo         area  \
# 0       Aguascalientes, Aguascalientes   1001  Aguascalientes  1168.762384
# 1             Asientos, Aguascalientes   1002  Aguascalientes   547.762077
# 2             Calvillo, Aguascalientes   1003  Aguascalientes   931.300088
# 3                Cosio, Aguascalientes   1004  Aguascalientes   128.907513
# 4             El Llano, Aguascalientes   1010  Aguascalientes   500.861359
# ...                                ...    ...             ...          ...
# 2475  Villa Gonzalez Ortega, Zacatecas  32053       Zacatecas   417.529939
# 2476          Villa Hidalgo, Zacatecas  32054       Zacatecas   355.528477
# 2477           Villa de Cos, Zacatecas  32051       Zacatecas  6405.541210
# 2478             Villanueva, Zacatecas  32055       Zacatecas  2158.696446
# 2479              Zacatecas, Zacatecas  32056       Zacatecas   444.547742
#
#             R1        R2        R3        R4      R4pt  region  sum_R1_R2_  \
# 0     0.360084  0.372695  0.117251  0.662296  0.000458  Centro    0.850030
# 1     0.019696  0.011381  0.017855  0.745202  0.000515  Centro    0.048932
# 2     0.019349  0.013107  0.013835  0.708078  0.000489  Centro    0.046292
# 3     0.012770  0.010345  0.012474  0.704691  0.000487  Centro    0.035590
# 4     0.012770  0.012417  0.011113  0.710027  0.000491  Centro    0.036300
# ...        ...       ...       ...       ...       ...     ...         ...
# 2475  0.011385  0.010000  0.010309  0.743417  0.000514  Centro    0.031694
# 2476  0.010346  0.010345  0.010928  0.747821  0.000517  Centro    0.031619
# 2477  0.014502  0.010691  0.011175  0.749266  0.000518  Centro    0.036367
# 2478  0.015194  0.013107  0.011856  0.747771  0.000517  Centro    0.040157
# 2479  0.101417  0.061474  0.024535  0.719606  0.000497  Centro    0.187426
#
#                                                geometry
# 0     POLYGON ((-11370403.590 2520317.662, -11368883...
# 1     POLYGON ((-11368305.122 2546014.561, -11367916...
# 2     POLYGON ((-11444356.824 2510725.426, -11444212...
# 3     POLYGON ((-11387740.145 2566722.259, -11387556...
# 4     POLYGON ((-11365483.996 2514328.561, -11364488...
# ...                                                 ...
# 2475  POLYGON ((-11348605.030 2589714.729, -11348882...
# 2476  POLYGON ((-11316391.676 2571964.813, -11316227...
# 2477  POLYGON ((-11435339.198 2727602.823, -11434798...
# 2478  POLYGON ((-11442165.843 2592830.025, -11441393...
# 2479  POLYGON ((-11448145.608 2612182.405, -11447252...
#
# [2480 rows x 12 columns]

# %%
# Assuming inm is your original DataFrame with 'latitud' and 'longitud' columns
# Create a GeoDataFrame
inm['geometry'] = inm.apply(lambda row: Point(row['longitud'], row['latitud']), axis=1)
gdf_inm = gpd.GeoDataFrame(inm, geometry='geometry')

# Set the CRS to EPSG:4326
gdf_inm.set_crs(epsg=4326, inplace=True)

# Verify the result
#print(gdf_inm)
# Out:
#     Unnamed: 0                                               name tipo  \
# 0            0                       Acayucan Estacion Migratoria  INM
# 1            1                   Agua Prieta Estacion Provisional  INM
# 2            2                 Aguascalientes Estacion Migratoria  INM
# 3            3                      Campeche Estacion Provisional  INM
# 4            4  Centro de Atencion Integral al Trafico Fronter...  INM
# 5            5  Centro de Atencion Integral al Transito Fronte...  INM
# 6            6                       Chetumal Estacion Migratoria  INM
# 7            7                      Chihuahua Estacion Migratoria  INM
# 8            8             Ciudad Cuauhtemoc Estacion Provisional  INM
# 9            9             Ciudad del Carmen Estacion Provisional  INM
# 10          10                  Ciudad Juarez Estacion Migratoria  INM
# 11          11                        Colima Estancia Provisional  INM
# 12          12                       Comitan Estacion Provisional  INM
# 13          13                     Echegaray Estacion Provisional  INM
# 14          14                      El Ceibo Estacion Provisional  INM
# 15          15                    El Hueyate Estacion Provisional  INM
# 16          16                      Escarcega Estacion Migratoria  INM
# 17          17                   Guadalajara Estacion Provisional  INM
# 18          18                     Hermosillo Estacion Migratoria  INM
# 19          19                      Huatulco Estancia Provisional  INM
# 20          20                     Huehuetan Estacion Provisional  INM
# 21          21  Iztapalapa Estacion Migratoria (Estacion Migra...  INM
# 22          22                          Janos Estacion Migratoria  INM
# 23          23                    La Ventosa Estacion Provisional  INM
# 24          24                      Matamoros Estacion Migratoria  INM
# 25          25                       Mazatlan Estacion Migratoria  INM
# 26          26                         Merida Estacion Migratoria  INM
# 27          27                       Mexicali Estacion Migratoria  INM
# 28          28                 Miguel Aleman Estacion Provisional  INM
# 29          29                     Monterrey Estacion Provisional  INM
# 30          30                   Nuevo Laredo Estacion Migratoria  INM
# 31          31                         Oaxaca Estacion Migratoria  INM
# 32          32                        Pachuca Estacion Migratoria  INM
# 33          33                       Palenque Estacion Migratoria  INM
# 34          34                       Palenque Estacion Migratoria  INM
# 35          35                Piedras Negras Estacion Provisional  INM
# 36          36            Playas de Catazaja Estacion Provisional  INM
# 37          37            Playas de Catazaja Estacion Provisional  INM
# 38          38                         Puebla Estacion Migratoria  INM
# 39          39                       Saltillo Estacion Migratoria  INM
# 40          40                       Saltillo Estacion Migratoria  INM
# 41          41    San Cristobal de las Casas Estacion Provisional  INM
# 42          42           San Gregorio Chamic Estacion Provisional  INM
# 43          43                San Luis Potosi Estacion Migratoria  INM
# 44          44         San Pedro Tapanatepec Estacion Provisional  INM
# 45          45                        Tampico Estacion Migratoria  INM
# 46          46          Tapachula Estacion Migratoria (Siglo XXI)  INM
# 47          47                      Tenosique Estacion Migratoria  INM
# 48          48                      Tenosique Estacion Migratoria  INM
# 49          49                        Tijuana Estacion Migratoria  INM
# 50          50                       Tlaxcala Estacion Migratoria  INM
# 51          51                       Torreon Estacion Provisional  INM
# 52          52               Tuxtla Gutierrez Estacion Migratoria  INM
# 53          53                       Veracruz Estacion Migratoria  INM
# 54          54                   Villahermosa Estacion Migratoria  INM
# 55          55                      Zacatecas Estacion Migratoria  INM
# 56          56                    Zihuatanejo Estacion Migratoria  INM
#
#                        sub_tipo    latitud    longitud  \
# 0       Estacion Migratoria INM  18.001851  -94.921076
# 1       Estacion Migratoria INM  31.332947 -109.560374
# 2       Estacion Migratoria INM  21.929551 -102.320223
# 3       Estacion Migratoria INM  19.845660  -90.539741
# 4   Centro de Atencion Integral  16.149934  -92.072111
# 5   Centro de Atencion Integral  15.162749  -92.532987
# 6       Estacion Migratoria INM  18.526295  -88.283332
# 7       Estacion Migratoria INM  28.642257 -106.084403
# 8       Estacion Migratoria INM  15.667668  -92.002344
# 9       Estacion Migratoria INM  18.642626  -91.823607
# 10      Estacion Migratoria INM  31.745586 -106.483964
# 11      Estacion Migratoria INM  18.526295  -88.283332
# 12      Estacion Migratoria INM  16.214324  -92.115576
# 13      Estacion Migratoria INM  15.654755  -93.149776
# 14      Estacion Migratoria INM  17.260287  -90.988373
# 15      Estacion Migratoria INM  15.160568  -92.515785
# 16      Estacion Migratoria INM  18.606645  -90.739388
# 17      Estacion Migratoria INM  20.726967 -103.345063
# 18      Estacion Migratoria INM  29.079571 -110.955262
# 19      Estacion Migratoria INM  15.827777  -96.320882
# 20      Estacion Migratoria INM  15.019603  -92.393178
# 21      Estacion Migratoria INM  19.316469  -99.083204
# 22      Estacion Migratoria INM  30.884843 -108.194389
# 23      Estacion Migratoria INM  16.548342  -94.948654
# 24      Estacion Migratoria INM  25.890848  -97.503147
# 25      Estacion Migratoria INM  23.192815 -106.419690
# 26      Estacion Migratoria INM  20.987216  -89.627130
# 27      Estacion Migratoria INM  32.585847 -115.438939
# 28      Estacion Migratoria INM  26.397943  -99.030118
# 29      Estacion Migratoria INM  25.642726 -100.318737
# 30      Estacion Migratoria INM  27.498089  -99.507208
# 31      Estacion Migratoria INM  17.061349  -96.722313
# 32      Estacion Migratoria INM  20.084752  -98.759365
# 33      Estacion Migratoria INM  17.494729  -91.986122
# 34      Estacion Migratoria INM  17.494729  -91.986122
# 35      Estacion Migratoria INM  28.680380 -100.573504
# 36      Estacion Migratoria INM  17.721218  -92.015991
# 37      Estacion Migratoria INM  17.721218  -92.015991
# 38      Estacion Migratoria INM  19.059846  -98.227322
# 39      Estacion Migratoria INM  25.422443 -100.944786
# 40      Estacion Migratoria INM  25.422443 -100.944786
# 41      Estacion Migratoria INM  16.734462  -92.649164
# 42      Estacion Migratoria INM  15.680229  -92.005692
# 43      Estacion Migratoria INM  22.143597 -100.997765
# 44      Estacion Migratoria INM  16.369762  -94.192357
# 45      Estacion Migratoria INM  22.263194  -97.795803
# 46      Estacion Migratoria INM  14.920195  -92.259107
# 47      Estacion Migratoria INM  17.457765  -91.445217
# 48      Estacion Migratoria INM  17.457765  -91.445217
# 49      Estacion Migratoria INM  32.471301 -117.013686
# 50      Estacion Migratoria INM  19.336626  -98.193398
# 51      Estacion Migratoria INM  25.538859 -103.453354
# 52      Estacion Migratoria INM  16.753920  -93.105268
# 53      Estacion Migratoria INM  19.199485  -96.140113
# 54      Estacion Migratoria INM  17.989956  -92.942932
# 55      Estacion Migratoria INM  22.765814 -102.578058
# 56      Estacion Migratoria INM  17.644247 -101.553969
#
#                         ciudad            estado id_poligon    region  \
# 0                     Acayucan          Veracruz     PG1378     Golfo
# 1                  Agua Prieta            Sonora      PG578  Pacifico
# 2               Aguascalientes    Aguascalientes      PG994    Centro
# 3                     Campeche          Campeche     PG1654       Sur
# 4                La Trinitaria           Chiapas     PG1531       Sur
# 5                Salto de Agua           Chiapas     PG1530       Sur
# 6                     Chetumal      Quintana Roo     PG1769       Sur
# 7                    Chihuahua         Chihuahua      PG769    Centro
# 8            Ciudad Cuauhtemoc           Chiapas     PG1531       Sur
# 9            Ciudad del Carmen          Campeche     PG1574       Sur
# 10               Ciudad Juarez         Chihuahua      PG774    Centro
# 11                      Colima      Quintana Roo     PG1769       Sur
# 12                     Comitan           Chiapas     PG1531       Sur
# 13                   Echegaray           Chiapas     PG1492       Sur
# 14                    El Ceibo           Tabasco     PG1611       Sur
# 15                  El Hueyate           Chiapas     PG1530       Sur
# 16                   Escarcega          Campeche     PG1613       Sur
# 17                 Guadalajara           Jalisco      PG914  Pacifico
# 18                  Hermosillo            Sonora      PG497  Pacifico
# 19                    Huatulco            Oaxaca     PG1297       Sur
# 20                   Huehuetan           Chiapas     PG1530       Sur
# 21                  Iztapalapa  Estado de Mexico     PG1146    Centro
# 22                       Janos         Chihuahua      PG655    Centro
# 23                  La Ventosa            Oaxaca     PG1376       Sur
# 24                   Matamoros        Tamaulipas     PG1272     Golfo
# 25                    Mazatlan           Sinaloa      PG761  Pacifico
# 26                      Merida           Yucatan     PG1694       Sur
# 27                    Mexicali   Baja California      PG268  Pacifico
# 28               Miguel Aleman        Tamaulipas     PG1156     Golfo
# 29                   Monterrey          Coahuila     PG1116     Golfo
# 30                Nuevo Laredo        Tamaulipas     PG1157     Golfo
# 31                      Oaxaca            Oaxaca     PG1299       Sur
# 32                     Pachuca           Hidalgo     PG1186    Centro
# 33                    Palenque           Tabasco     PG1572     Golfo
# 34                    Palenque           Tabasco     PG1572       Sur
# 35              Piedras Negras          Coahuila     PG1081    Centro
# 36          Playas de Catazaja           Chiapas     PG1534     Golfo
# 37          Playas de Catazaja           Chiapas     PG1534       Sur
# 38                      Puebla            Puebla     PG1223    Centro
# 39                    Saltillo          Coahuila     PG1077     Golfo
# 40                    Saltillo          Coahuila     PG1077    Centro
# 41  San Cristobal de las Casas           Chiapas     PG1532       Sur
# 42         San Gregorio Chamic           Chiapas     PG1531       Sur
# 43             San Luis Potosi   San Luis Potosi     PG1072    Centro
# 44       San Pedro Tapanatepec            Oaxaca     PG1415       Sur
# 45                     Tampico          Veracruz     PG1228     Golfo
# 46                   Tapachula           Chiapas     PG1530       Sur
# 47                   Tenosique           Tabasco     PG1572     Golfo
# 48                   Tenosique           Tabasco     PG1572       Sur
# 49                     Tijuana   Baja California      PG190  Pacifico
# 50                    Tlaxcala            Puebla     PG1224    Centro
# 51                     Torreon          Coahuila      PG921    Centro
# 52            Tuxtla Gutierrez           Chiapas     PG1493       Sur
# 53                    Veracruz          Veracruz     PG1341     Golfo
# 54                Villahermosa           Chiapas     PG1495     Golfo
# 55                   Zacatecas    Aguascalientes      PG956    Centro
# 56                 Zihuatanejo          Guerrero     PG1026  Pacifico
#
#                        geometry
# 0    POINT (-94.92108 18.00185)
# 1   POINT (-109.56037 31.33295)
# 2   POINT (-102.32022 21.92955)
# 3    POINT (-90.53974 19.84566)
# 4    POINT (-92.07211 16.14993)
# 5    POINT (-92.53299 15.16275)
# 6    POINT (-88.28333 18.52630)
# 7   POINT (-106.08440 28.64226)
# 8    POINT (-92.00234 15.66767)
# 9    POINT (-91.82361 18.64263)
# 10  POINT (-106.48396 31.74559)
# 11   POINT (-88.28333 18.52630)
# 12   POINT (-92.11558 16.21432)
# 13   POINT (-93.14978 15.65475)
# 14   POINT (-90.98837 17.26029)
# 15   POINT (-92.51579 15.16057)
# 16   POINT (-90.73939 18.60665)
# 17  POINT (-103.34506 20.72697)
# 18  POINT (-110.95526 29.07957)
# 19   POINT (-96.32088 15.82778)
# 20   POINT (-92.39318 15.01960)
# 21   POINT (-99.08320 19.31647)
# 22  POINT (-108.19439 30.88484)
# 23   POINT (-94.94865 16.54834)
# 24   POINT (-97.50315 25.89085)
# 25  POINT (-106.41969 23.19282)
# 26   POINT (-89.62713 20.98722)
# 27  POINT (-115.43894 32.58585)
# 28   POINT (-99.03012 26.39794)
# 29  POINT (-100.31874 25.64273)
# 30   POINT (-99.50721 27.49809)
# 31   POINT (-96.72231 17.06135)
# 32   POINT (-98.75937 20.08475)
# 33   POINT (-91.98612 17.49473)
# 34   POINT (-91.98612 17.49473)
# 35  POINT (-100.57350 28.68038)
# 36   POINT (-92.01599 17.72122)
# 37   POINT (-92.01599 17.72122)
# 38   POINT (-98.22732 19.05985)
# 39  POINT (-100.94479 25.42244)
# 40  POINT (-100.94479 25.42244)
# 41   POINT (-92.64916 16.73446)
# 42   POINT (-92.00569 15.68023)
# 43  POINT (-100.99777 22.14360)
# 44   POINT (-94.19236 16.36976)
# 45   POINT (-97.79580 22.26319)
# 46   POINT (-92.25911 14.92020)
# 47   POINT (-91.44522 17.45777)
# 48   POINT (-91.44522 17.45777)
# 49  POINT (-117.01369 32.47130)
# 50   POINT (-98.19340 19.33663)
# 51  POINT (-103.45335 25.53886)
# 52   POINT (-93.10527 16.75392)
# 53   POINT (-96.14011 19.19949)
# 54   POINT (-92.94293 17.98996)
# 55  POINT (-102.57806 22.76581)
# 56  POINT (-101.55397 17.64425)

# %%
sc.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0            organization name  \
# 0              0                          NaN
# 1              1                          NaN
# 2              2                          NaN
# 3              3                          NaN
# 4              4                          NaN
# ...          ...                          ...
# 1163        1163                          NaN
# 1164        1164  Casa para Menores Migrantes
# 1165        1165                          NaN
# 1166        1166                          NaN
# 1167        1167            Módulo Fronterizo
#
#                                           facility name  \
# 0     Oficina de la Comisión Nacional de los Derecho...
# 1                              Unidad Regional Acapulco
# 2           ACNUR Agencia de la ONU para los Regufiados
# 3           Agencia Consular de El Salvador en Acayucan
# 4             Agencia Consular de Guatemala en Acayucan
# ...                                                 ...
# 1163                          Unidad Regional Zitácuaro
# 1164                                          Casa YMCA
# 1165  Casa del Migrante para Niñas y Niños No Acompa...
# 1166          Consulado General de Honduras en Veracruz
# 1167                                Juntos en el Camino
#
#                                                    tipo  \
# 0     Justicia / Derechos Humanos / Seguridad / Orga...
# 1              Institucion publica / Educacion y Empleo
# 2     Justicia / Derechos Humanos / Seguridad / Orga...
# 3                                            Consulados
# 4                                            Consulados
# ...                                                 ...
# 1163           Institucion publica / Educacion y Empleo
# 1164                            Albergue y Alimentacion
# 1165                            Mujer, Niñez y Juventud
# 1166                                         Consulados
# 1167                            Albergue y Alimentacion
#
#                                               direccion    latitud  \
# 0     Calle Cristóbal Colón 12, Fraccionamiento Cost...  16.850921
# 1     Calle Laurel No. 3, Col. El Roble, Acapulco de...  16.867548
# 2                                         no disponible  17.953529
# 3     Melchor Ocampo Norte 1212, entre 5 de mayo y G...  17.954887
# 4     Calle Independencia, esq. Altamirano, Barrio e...  17.950304
# ...                                                 ...        ...
# 1163  Calle Cuauhtémoc Oriente No. 17, Col. Centro, ...  19.438395
# 1164  Blvd. Cuauhtémoc Sur 3170, Col. Chula vista C....  32.640054
# 1165  Avenida Bonampak, esquina Chocol-Ha s/n, Col. ...  21.378499
# 1166  Blvd. Manuel Ávila Camacho 343, Col. Ricardo F...  19.195967
# 1167    Garita 1, Carretera Mexicali-Calexico, Módulo 3  32.678948
#
#         longitud     estado           municipio  \
# 0     -99.850158   Guerrero  Acapulco de Juarez
# 1     -99.873576   Guerrero  Acapulco de Juarez
# 2     -94.916254   Veracruz            Acayucan
# 3     -94.915622   Veracruz            Acayucan
# 4     -94.908594   Veracruz            Acayucan
# ...          ...        ...                 ...
# 1163 -100.353671  Michoacan           Zitacuaro
# 1164 -117.084196    Tijuana     Baja California
# 1165  -86.399385     Cancun        Quintana Roo
# 1166  -96.129029   Veracruz            Veracruz
# 1167 -115.498883   Mexicali     Baja California
#
#                                         geometry  \
# 0                 POINT (-99.8501576 16.8509213)
# 1          POINT (-99.87357620000002 16.8675479)
# 2                 POINT (-94.9162539 17.9535286)
# 3                 POINT (-94.9156218 17.9548865)
# 4                 POINT (-94.9085939 17.9503035)
# ...                                          ...
# 1163              POINT (-100.353671 19.4383952)
# 1164             POINT (-117.0841955 32.6400541)
# 1165  POINT (-86.3993846705623 21.3784987878732)
# 1166              POINT (-96.1290289 19.1959673)
# 1167             POINT (-115.4988834 32.6789476)
#
#                                                  fuente    region
# 0     OIM Directorio Asistencia a Personas migrantes...  Pacifico
# 1     OIM Directorio Asistencia a Personas migrantes...  Pacifico
# 2                      OIM Directorio Virtual Servicios     Golfo
# 3     OIM Directorio Asistencia a Personas migrantes...     Golfo
# 4     OIM Directorio Asistencia a Personas migrantes...     Golfo
# ...                                                 ...       ...
# 1163  OIM Directorio Asistencia a Personas migrantes...  Pacifico
# 1164  OIM Directorio Asistencia a Personas migrantes...       NaN
# 1165  OIM Directorio Asistencia a Personas migrantes...       NaN
# 1166  OIM Directorio Asistencia a Personas migrantes...     Golfo
# 1167  OIM Directorio Asistencia a Personas migrantes...       NaN
#
# [1168 rows x 12 columns]>

# %%
mun_shp.head(1)
# Out:
#                            nommun cvemun          nomedo         area  \
# 0  Aguascalientes, Aguascalientes   1001  Aguascalientes  1168.762384
#
#          R1        R2        R3        R4      R4pt  region  sum_R1_R2_  \
# 0  0.360084  0.372695  0.117251  0.662296  0.000458  Centro     0.85003
#
#                                             geometry
# 0  POLYGON ((-11370403.590 2520317.662, -11368883...

# %% [markdown]
# ### subdfs

# %%
sub_dfval = pd.read_csv('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\UFLP\\df_valores.csv')
#gdf_inm.to_csv('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\UFLP\\inm.csv')

# %%
# Sort cities by demand (eventos) in descending order
sub_dfval = sub_dfval.sort_values(by='eventos', ascending=False).reset_index(drop=True)
# Convert 'geometry_wkt' column from WKT to geometry
sub_dfval['geometry'] = sub_dfval['geometry'].apply(wkt.loads)

# Create GeoDataFrames if not already
sub_dfval = gpd.GeoDataFrame(sub_dfval, geometry='geometry')
#facilities = gpd.GeoDataFrame(facilities, geometry='geometry', crs=sub_dfval.crs)

# %%
# Define a function to create a circular buffer around each city centroid
def create_buffer(geom, radius_km):
    return geom.buffer(radius_km / 110.574)  # Conversion from km to degrees

# Assuming sub_dfval is already loaded with the required columns 'geometry' and 'eventos'
# Create a 30km buffer around each city centroid
sub_dfval['buffer'] = sub_dfval['geometry'].apply(create_buffer, radius_km=30)

# %%
sub_dfval = sub_dfval.sort_values(by='eventos', ascending=False).reset_index(drop=True)

# %%
sub_dfval.head()
# Out:
#    Unnamed: 0                                     nommun   cvemun  \
# 0           0             Aguascalientes, Aguascalientes  19039.0
# 1           1                      Cosio, Aguascalientes  20184.0
# 2           2                Jesus Maria, Aguascalientes  10013.0
# 3           3  San Francisco de los Romo, Aguascalientes  17007.0
# 4           4                   Tijuana, Baja California   2004.0
#
#             estado    region id_poligon  eventos  inm_30km  sc_30km  \
# 0   Aguascalientes    Centro      PG955       44         1       45
# 1   Aguascalientes    Centro      PG994       98         0        0
# 2   Aguascalientes    Centro      PG994      399         1       45
# 3   Aguascalientes    Centro      PG994       18         1       44
# 4  Baja California  Pacifico      PG190    27405         1       47
#
#                                geometry
# 0       POINT (-102.5000001 22.0000001)
# 1  POINT (-102.312008510523 22.3705155)
# 2  POINT (-102.468451716512 21.9345555)
# 3       POINT (-102.2707133 22.0746282)
# 4        POINT (-117.019529 32.5317397)

# %%
# List of columns to include in the sub-DataFrame
columns_to_include = ['nommun', 'cvemun', 'estado', 'region', 'id_poligon', 'eventos', 'sc_30km']

# Create the sub-DataFrame by selecting the columns
#sub_df_sc = dfvalores[columns_to_include]

# %%
sub_dfval.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 389 entries, 0 to 388
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   nommun        389 non-null    object
#  1   cvemun        294 non-null    float64
#  2   estado        389 non-null    object
#  3   region        389 non-null    object
#  4   id_poligon    389 non-null    object
#  5   eventos       374 non-null    float64
#  6   inm_30km      389 non-null    int64
#  7   sc_30km       389 non-null    int64
#  8   geometry      389 non-null    object
#  9   geometry_wkt  389 non-null    object
# dtypes: float64(2), int64(2), object(6)
# memory usage: 30.5+ KB

# %% [markdown]
# #### methodologies

# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point, Polygon
import pulp
import matplotlib.pyplot as plt

# %% [markdown]
# #### scenario a: inm
#
# to begin now i want to do the UFLP excerse to get a sintetic optimal distribution of the original size of Fa wich is 57.
#
# Meaning that we have to reproduce the location of 57 points, with their coordinates, based on this criteria:
#
# since in my case every cite of transit has a demand D, that varies accordingly, and it represents how much its needed but also thats gonna be topped depending on other points nearby.
#
# for example in scenario a: the criteria would look like this...
#  1) the 57 new locations are going to be assigned to the most needed first, meaning that locations with the most demand (Di) should be prioritized, but assignations are gonna be capped to just one facility for each transit city or node (i). unless [this is very important] the algorithm assigns a Facility To a diferent node (i) and it happens that this facility F also intersect with the 30km radius circle of a node i that was already satisfied.
#
# 2) assignations should be made in a way that they try to satisfy locations with most Di, but at the same time try and intersect with other nearby locations in the range, also trying to cover as much D as possible (or as many cities as they can, which would be the same).
#
#     -we have 389 city nodes
#
#
#    experiment 1
#    -Original Fa is 57 facilities
#
#
#     experiment  and so,
#    -facilities increase in 1 for each experiment, until every city is covered using as less facilities as possible.

# %% [markdown]
# In this exercise, we'll prioritize placing the facilities in the most needed areas based on the demand
# 𝐷𝑖
# and ensure that each facility can cover as much demand as possible within the 30km range.

# %% [markdown]
# To solve the Uncapacitated Facility Location Problem (UFLP) with the given criteria, we can follow these steps:
#
# Define the problem: Formulate the UFLP as a mathematical optimization problem.
# Set up the data: Define the demand for each transit city and create the necessary circular polygons to determine intersections.
# Formulate the model: Use a linear programming solver to define the decision variables, objective function, and constraints.
# Solve the model: Use a solver to find the optimal solution.

# %% [markdown]
# In this section, we implement a greedy algorithm to solve the Uncapacitated Facility Location Problem (UFLP) for placing 57 facilities optimally based on demand. Each city (node) in the dataset has a centroid and a demand value (D). The goal is to place facilities to cover as much demand as possible while ensuring that facilities can serve multiple nearby cities within a 30km radius.

# %%
import os

# Ruta base donde se crearán las carpetas
base_path = r'C:\Users\puria\Documents\articulo\Mapa_Migracion_Irregular_Mexico\1. Mapas\1. Mapas\Metodo_1\UFLP'

# Lista de números para las carpetas
folder_numbers = range(67, 128, 10)  # 67, 77, ..., 127

# Crear cada carpeta
for number in folder_numbers:
    folder_name = f"{number} opt"
    folder_path = os.path.join(base_path, folder_name)
    
    # Crea la carpeta si no existe
    os.makedirs(folder_path, exist_ok=True)
    print(f"Creada carpeta: {folder_path}")
# Out:
# Creada carpeta: C:\Users\puria\Documents\articulo\Mapa_Migracion_Irregular_Mexico\1. Mapas\1. Mapas\Metodo_1\UFLP\67 opt
# Creada carpeta: C:\Users\puria\Documents\articulo\Mapa_Migracion_Irregular_Mexico\1. Mapas\1. Mapas\Metodo_1\UFLP\77 opt
# Creada carpeta: C:\Users\puria\Documents\articulo\Mapa_Migracion_Irregular_Mexico\1. Mapas\1. Mapas\Metodo_1\UFLP\87 opt
# Creada carpeta: C:\Users\puria\Documents\articulo\Mapa_Migracion_Irregular_Mexico\1. Mapas\1. Mapas\Metodo_1\UFLP\97 opt
# Creada carpeta: C:\Users\puria\Documents\articulo\Mapa_Migracion_Irregular_Mexico\1. Mapas\1. Mapas\Metodo_1\UFLP\107 opt
# Creada carpeta: C:\Users\puria\Documents\articulo\Mapa_Migracion_Irregular_Mexico\1. Mapas\1. Mapas\Metodo_1\UFLP\117 opt
# Creada carpeta: C:\Users\puria\Documents\articulo\Mapa_Migracion_Irregular_Mexico\1. Mapas\1. Mapas\Metodo_1\UFLP\127 opt

# %%
#sub_dfval.to_csv('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\UFLP\\57 opt\\sub_dfval57.csv')
#facilities.to_file('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\UFLP\\57 opt\\facilities57.shp')

#sub_dfval.to_csv('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\UFLP\\67 opt\\sub_dfval67.csv')
#facilities.to_file('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\UFLP\\67 opt\\facilities67.shp')

# Guardar sub_dfval y facilities para 87
sub_dfval.to_csv('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\UFLP\\77 opt\\sub_dfval77.csv')
facilities.to_file('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\UFLP\\77 opt\\facilities77.shp')



# Guardar sub_dfval y facilities para 87
#sub_dfval.to_csv('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\UFLP\\87 opt\\sub_dfval87.csv')
#facilities.to_file('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\UFLP\\87 opt\\facilities87.shp')


# Guardar sub_dfval y facilities para 97
#sub_dfval.to_csv('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\UFLP\\97 opt\\sub_dfval97.csv')
#facilities.to_file('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\UFLP\\97 opt\\facilities97.shp')

# %%
#facilities.to_file('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\UFLP\\facilities.shp')

# %%
sub_dfval = pd.read_csv('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\UFLP\\57 status quo\\df_valores.csv')
#gdf_inm.to_csv('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\UFLP\\inm.csv')

# %% [markdown]
# ## data preparation

# %%
sub_dfval = sub_dfval.sort_values(by='eventos', ascending=False).reset_index(drop=True)
sub_dfval['geometry'] = sub_dfval['geometry'].apply(wkt.loads)
sub_dfval = gpd.GeoDataFrame(sub_dfval, geometry='geometry')

# Define a function to create a circular buffer around each city centroid
def create_buffer(geom, radius_km):
    return geom.buffer(radius_km / 110.574)  # Conversion from km to degrees

# Create a 30km buffer around each city centroid
sub_dfval['buffer'] = sub_dfval['geometry'].apply(create_buffer, radius_km=30)
sub_dfval['facility_count'] = 0  # Initialize facility count column

# %%
sub_dfval.head()
# Out:
#    Unnamed: 0                                     nommun   cvemun  \
# 0           0             Aguascalientes, Aguascalientes  19039.0
# 1           1                      Cosio, Aguascalientes  20184.0
# 2           2                Jesus Maria, Aguascalientes  10013.0
# 3           3  San Francisco de los Romo, Aguascalientes  17007.0
# 4           4                   Tijuana, Baja California   2004.0
#
#             estado    region id_poligon  eventos  inm_30km  sc_30km  \
# 0   Aguascalientes    Centro      PG955       44         1       45
# 1   Aguascalientes    Centro      PG994       98         0        0
# 2   Aguascalientes    Centro      PG994      399         1       45
# 3   Aguascalientes    Centro      PG994       18         1       44
# 4  Baja California  Pacifico      PG190    27405         1       47
#
#                                geometry
# 0       POINT (-102.5000001 22.0000001)
# 1  POINT (-102.312008510523 22.3705155)
# 2  POINT (-102.468451716512 21.9345555)
# 3       POINT (-102.2707133 22.0746282)
# 4        POINT (-117.019529 32.5317397)

# %%
sub_dfval['geometry'] = sub_dfval['geometry'].apply(wkt.loads)

# %% [markdown]
# ### basic code

# %%
# Delete all data including structure
facilities = pd.DataFrame()
# Initialize a GeoDataFrame to store the new facility locations
facilities = gpd.GeoDataFrame(columns=['geometry'], crs=sub_dfval.crs)
# Verify the DataFrame is completely empty
print(facilities)
# Out:
# Empty GeoDataFrame
# Columns: [geometry]
# Index: []

# %%
# Number of facilities to place
num_facilities = 1168

# Prepare to store facilities
facilities = gpd.GeoDataFrame(columns=['geometry'], crs=sub_dfval.crs)

# List to keep track of which cities are covered by which facility
coverage_tracker = {}

for _ in range(num_facilities):
    # Find the city with the highest uncovered demand
    highest_demand = 0
    best_city = None

    for idx, row in sub_dfval.iterrows():
        if sub_dfval.at[idx, 'facility_count'] == 0 or not any(row['geometry'].intersects(coverage_tracker.get(idx, []))):
            current_demand = row['eventos']
            if current_demand > highest_demand:
                highest_demand = current_demand
                best_city = row
                best_idx = idx

    if best_city is not None:
        new_facility = best_city['geometry']
        new_facility_gdf = gpd.GeoDataFrame([[new_facility]], columns=['geometry'], crs=sub_dfval.crs)
        facilities = pd.concat([facilities, new_facility_gdf], ignore_index=True)

        # Find all cities within the buffer range and update their coverage count
        for jdx, city in sub_dfval.iterrows():
            if city['buffer'].intersects(new_facility):
                sub_dfval.at[jdx, 'facility_count'] += 1
                if jdx in coverage_tracker:
                    coverage_tracker[jdx].append(new_facility)
                else:
                    coverage_tracker[jdx] = [new_facility]

# Print the resulting facilities and the updated sub_dfval
print(facilities.head())
print(sub_dfval[['nommun', 'facility_count']].head())
# Out:
#                      geometry
# 0  POINT (-93.66344 17.76210)
# 1  POINT (-92.77479 18.02716)
# 2  POINT (-92.26093 14.90429)
# 3  POINT (-91.42202 17.47071)
# 4  POINT (-94.91458 17.94879)
#                   nommun  facility_count
# 0  Huimanguillo, Tabasco               1
# 1        Centro, Tabasco               1
# 2     Tapachula, Chiapas               5
# 3     Tenosique, Tabasco               1
# 4     Acayucan, Veracruz               3

# %%
#sub_dfval.to_csv('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\UFLP\\57 status quo\\sub_dfval57.csv')
#facilities.to_file('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\UFLP\\57 status quo\\facilities57.shp')

#sub_dfval.to_csv('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\UFLP\\57 opt\\sub_dfval57.csv')
#facilities.to_file('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\UFLP\\57 opt\\facilities57.shp')

#sub_dfval.to_csv('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\UFLP\\67 opt\\sub_dfval67.csv')
#facilities.to_file('C:\\Users\\puria\\Documents\\articulo\\Mapa_Migracion_Irregular_Mexico\\1. Mapas\\1. Mapas\\Metodo_1\\UFLP\\67 opt\\facilities67.shp')

# %% [markdown]
# ####greedy para sc
#
# no ja

# %% [markdown]
# ## guardando each plot

# %%
facilities
# Out:
#                         geometry
# 0     POINT (-93.66344 17.76210)
# 1     POINT (-92.77479 18.02716)
# 2     POINT (-92.26093 14.90429)
# 3     POINT (-91.42202 17.47071)
# 4     POINT (-94.91458 17.94879)
# ..                           ...
# 383   POINT (-98.63643 20.01813)
# 384   POINT (-92.51921 16.97172)
# 385   POINT (-90.05108 20.36951)
# 386   POINT (-98.55525 20.22315)
# 387  POINT (-103.51065 19.69735)
#
# [388 rows x 1 columns]

# %% [markdown]
# ## plots

# %%
#original distribution 57 facility
# Plotting
fig, ax = plt.subplots(figsize=(10, 10))

# Plot the cities (sub_dfval) in blue
sub_dfval.plot(ax=ax, color='blue', markersize=5, label='Cities')

# Plot the facilities in red
facilities.plot(ax=ax, color='red', markersize=20, label='Facilities')

# Add a legend
#plt.legend()

# Add a title
#plt.title('87')

# Show the plot
plt.show()

# %%
#original distribution 57 facility
# Plotting
fig, ax = plt.subplots(figsize=(10, 10))

# Plot the cities (sub_dfval) in blue
sub_dfval.plot(ax=ax, color='blue', markersize=5, label='Cities')

# Plot the facilities in red
gdf_inm.plot(ax=ax, color='red', markersize=20, label='Facilities')

# Add a legend
#plt.legend()

# Add a title
plt.title('status quo 57')

# Show the plot
plt.show()

# %%
# Confirm the 'costo' column is recognized
if 'costo' in dfval.columns:
    print("Column 'costo' is ready to be used.")
else:
    print("Column 'costo' not found, check DataFrame loading and column names.")
# Out:
# Column 'costo' is ready to be used.

# %%
dfval.head()
# Out:
#    Unnamed: 0                 nommun region  eventos  sc_30km  distancia_km  \
# 0           0     Tapachula, Chiapas    Sur  70665.0       67        15.537
# 1           1  Huimanguillo, Tabasco    Sur  86684.0        0       325.527
# 2           2        Centro, Tabasco    Sur  74160.0        7       224.089
# 3           4     Tenosique, Tabasco    Sur  39620.0       34        42.334
# 4           5     Macuspana, Tabasco    Sur  31739.0        3       177.427
#
#      latitud                              geometry  sum_R1_R2_        R4  \
# 0  14.904291        POINT (-92.2609265 14.9042905)    0.425404  0.470409
# 1  17.762097  POINT (-93.6634408051158 17.7620967)    0.102185  0.497342
# 2  18.027159  POINT (-92.7747911804616 18.0271588)    1.192250  0.469173
# 3  17.470713        POINT (-91.4220212 17.4707129)    0.360015  0.496657
# 4  17.760922          POINT (-92.596108 17.760922)    0.272972  0.495978
#
#           R     costo
# 0  0.447906  5.001190
# 1  0.299763  3.408318
# 2  0.830711  9.315579
# 3  0.428336  4.534835
# 4  0.384475  3.985202

# %%
print(dfval.columns)
dfval.columns = dfval.columns.str.strip()
# Out:
# Index(['Unnamed: 0', 'nommun', 'region', 'eventos', 'sc_30km', 'distancia_km',
#        'latitud', 'geometry', 'sum_R1_R2_', 'R4', 'R', 'costo'],
#       dtype='object')

# %%
facilities
# Out:
#                         geometry
# 0     POINT (-93.66344 17.76210)
# 1     POINT (-92.77479 18.02716)
# 2     POINT (-92.26093 14.90429)
# 3     POINT (-91.42202 17.47071)
# 4     POINT (-94.91458 17.94879)
# ...                          ...
# 1163  POINT (-93.66344 17.76210)
# 1164  POINT (-93.66344 17.76210)
# 1165  POINT (-93.66344 17.76210)
# 1166  POINT (-93.66344 17.76210)
# 1167  POINT (-93.66344 17.76210)
#
# [1168 rows x 1 columns]

# %%
dfvalores = pd.read_csv('/Users/pablouriarte/Mapa_Migracion_Irregular_Mexico_Fresh/1. Mapas/1. Mapas/Metodo_1/df_valores_rutas.csv')
dfvaloresopt57 = pd.read_csv('/Users/pablouriarte/Mapa_Migracion_Irregular_Mexico_Fresh/1. Mapas/1. Mapas/Metodo_1/UFLP/57 opt/sub_dfvalvul1.csv')

# %%
dfvaloresopt57
# Out:
#      Unnamed: 0                         nommun    estado  eventos  inm_30km  \
# 0             0             Tapachula, Chiapas   Chiapas  70665.0         2
# 1             1          Huimanguillo, Tabasco   Tabasco  86684.0         0
# 2             2                Centro, Tabasco   Tabasco  74160.0         1
# 3             3             Acayucan, Veracruz  Veracruz  36446.0         1
# 4             4             Tenosique, Tabasco   Tabasco  39620.0         1
# ..          ...                            ...       ...      ...       ...
# 384         384  San Juan Huactzinco, Tlaxcala  Tlaxcala      1.0         2
# 385         385   Amaxac de Guerrero, Tlaxcala  Tlaxcala      1.0         1
# 386         386           Chicomuselo, Chiapas   Chiapas      NaN         0
# 387         387   Carlos A. Carrillo, Veracruz  Veracruz      1.0         0
# 388         388         Puerto Penasco, Sonora    Sonora      1.0         0
#
#      distancia_metros    latitud  facility_count_57  facility_count_67  \
# 0             15537.0  14.904291                  4                  5
# 1            325527.0  17.762097                  1                  1
# 2            224089.0  18.027159                  1                  1
# 3            448302.0  17.948786                  2                  2
# 4             42334.0  17.470713                  1                  1
# ..                ...        ...                ...                ...
# 384          879483.0  19.232933                  3                  3
# 385          898212.0  19.348889                  3                  3
# 386           85686.0  15.793552                  0                  0
# 387          544400.0  18.328361                  1                  1
# 388         3274463.0  31.317087                  0                  0
#
#      facility_count_77  facility_count_87  facility_count_97
# 0                    5                  5                  5
# 1                    1                  1                  1
# 2                    1                  1                  1
# 3                    2                  2                  2
# 4                    1                  1                  1
# ..                 ...                ...                ...
# 384                  4                  4                  4
# 385                  3                  3                  3
# 386                  0                  0                  0
# 387                  1                  1                  1
# 388                  0                  0                  0
#
# [389 rows x 12 columns]

# %%
import pandas as pd

# Suponiendo que dfvaloresopt57 es tu DataFrame
dfvaloresopt57['difference'] = dfvaloresopt57['facility_count_57'] - dfvaloresopt57['inm_30km']

# %%
# Ordenando para encontrar los mayores aumentos
top_increases = dfvaloresopt57.sort_values(by='difference', ascending=False).head(4)

# Ordenando para encontrar las mayores disminuciones
top_decreases = dfvaloresopt57.sort_values(by='difference', ascending=True).head(4)

# %%
print("\nTop Facility need per city, based on UFLP OPT 57:")
print(top_increases[['nommun', 'inm_30km', 'facility_count_57', 'difference']])

print("\nTop Facility descreses per city, considering re arrangement UFLP OPT 57:")
print(top_decreases[['nommun', 'inm_30km', 'facility_count_57', 'difference']])
# Out:
# Top Facility need per city, based on UFLP OPT 57:
#                                     nommun  inm_30km  facility_count_57  \
# 21                         Jalapa, Tabasco         0                  4
# 119  Ecatepec de Morelos, Estado de Mexico         0                  3
# 18                      Tacotalpa, Tabasco         0                  3
# 16                          Teapa, Tabasco         0                  3
#
#      difference
# 21            4
# 119           3
# 18            3
# 16            3
#
# Top Facility descreses per city, considering re arrangement UFLP OPT 57:
#                             nommun  inm_30km  facility_count_57  difference
# 76      Frontera Comalapa, Chiapas         2                  0          -2
# 267          Bacalar, Quintana Roo         2                  0          -2
# 105  Comitan de Dominguez, Chiapas         2                  0          -2
# 123         La Trinitaria, Chiapas         2                  0          -2

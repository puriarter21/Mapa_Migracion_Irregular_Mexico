# %%
import pandas as pd
from geopy.geocoders import Photon
from unidecode import unidecode
import unidecode

# %%
# Cargar el archivo CSV
datos_csv_ = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/3. mapas/3. Rutas/1. rutas_raw/Ciudades_Rutas_Final.csv')

# %% [markdown]
# ### Rutas Casillas_2008

# %%
datos_csv_.head(60)
# Out:
#                                 Ciudad            Estado  \
# 0                       Puebla, Puebla            Puebla
# 1                   Tlaxcala, Tlaxcala          Tlaxcala
# 2           Lecheria, Estado de Mexico  Estado de Mexico
# 3             Tijuana, Baja California   Baja California
# 4            Mexicali, Baja California   Baja California
# 5        San Luis Rio Colorado, Sonora            Sonora
# 6                      Sonoyta, Sonora            Sonora
# 7                      Nogales, Sonora            Sonora
# 8                  Agua Prieta, Sonora            Sonora
# 9             Ciudad Juarez, Chihuahua         Chihuahua
# 10                  Ojinaga, Chihuahua         Chihuahua
# 11            Piedras Negras, Coahuila          Coahuila
# 12            Nuevo Laredo, Tamaulipas        Tamaulipas
# 13                 Reynosa, Tamaulipas        Tamaulipas
# 14               Matamoros, Tamaulipas        Tamaulipas
# ...

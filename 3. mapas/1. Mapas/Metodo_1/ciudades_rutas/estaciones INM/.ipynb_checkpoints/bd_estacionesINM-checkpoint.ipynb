# %%
import pandas as pd
from geopy.geocoders import Photon
from geopy.geocoders import Nominatim
from unidecode import unidecode
import unidecode

# %%
import numpy as np
from shapely.geometry import Point, Polygon

# %%
import geopandas as gpd

# %%
ruta_archivo = '/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/3. mapas/1. Mapas/Metodo_1/ciudades_rutas/estaciones INM/inm_gdp.csv'

# Cargar el archivo .xls en un DataFrame
df = pd.read_csv(ruta_archivo)

# %%
grid = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/3. mapas/1. Mapas/Metodo_1/ciudades_rutas/ciudades detenciones/grid.csv')

# %%
grid
# Out:
#      ID_Poligono                                           geometry
# 0            PG1  POLYGON ((-120.00000 10.00000, -119.00000 10.0...
# 1            PG2  POLYGON ((-120.00000 11.00000, -119.00000 11.0...
# 2            PG3  POLYGON ((-120.00000 12.00000, -119.00000 12.0...
# 3            PG4  POLYGON ((-120.00000 13.00000, -119.00000 13.0...
# 4            PG5  POLYGON ((-120.00000 14.00000, -119.00000 14.0...
# ...          ...                                                ...
# 1021      PG1022  POLYGON ((-83.00000 32.00000, -82.00000 32.000...
# 1022      PG1023  POLYGON ((-83.00000 33.00000, -82.00000 33.000...
# 1023      PG1024  POLYGON ((-83.00000 34.00000, -82.00000 34.000...
# 1024      PG1025  POLYGON ((-83.00000 35.00000, -82.00000 35.000...
# 1025      PG1026  POLYGON ((-83.00000 36.00000, -82.00000 36.000...
#
# [1026 rows x 2 columns]

# %% [markdown]
# ### Procesamiento

# %% [markdown]
# 1) Asegúrate de que 'grid' es un DataFrame y tiene una columna 'geometry' que podría estar en formato de cadena

# %%
from shapely.wkt import loads
if 'geometry' in grid.columns:
    # Convertir cadenas de geometría a objetos geométricos usando `loads` de Shapely
    grid['geometry'] = grid['geometry'].apply(lambda x: loads(x) if isinstance(x, str) else x)

    # Ahora que todos los valores en 'geometry' son objetos geométricos, crea el GeoDataFrame
    grid = gpd.GeoDataFrame(grid, geometry='geometry')
else:
    print("La columna 'geometry' no existe en 'grid'.")

# %% [markdown]
# 2) hacemos un join con los puntos xy de cada ubicacion y le asignamos su ID_poligono en el grid

# %%
# Convertir df1 en GeoDataFrame
gdf1 = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.longitud, df.latitud))

# Aquí estoy asumiendo que tus datos están en WGS84 (EPSG:4326)
gdf1.set_crs(epsg=4326, inplace=True)
grid.set_crs(epsg=4326, inplace=True)

# Realizar la operación sjoin
gdf1_sjoined = gpd.sjoin(gdf1, grid, how="left", op="within")

# Asignar los 'ID_Poligono' a df1 desde el resultado del sjoin
df["ID_Poligono"] = gdf1_sjoined["ID_Poligono"]

# Verificar los resultados
print(df.head())
# Out:
#                                                 name tipo  \
# 0                       Acayucan Estacion Migratoria  INM
# 1                   Agua Prieta Estacion Provisional  INM
# 2                 Aguascalientes Estacion Migratoria  INM
# 3                      Campeche Estacion Provisional  INM
# 4  Centro de Atencion Integral al Trafico Fronter...  INM
#
#                       sub_tipo    latitud    longitud ID_Poligono
# 0      Estacion Migratoria INM  18.001851  -94.921076       PG685
# 1      Estacion Migratoria INM  31.332947 -109.560374       PG293
# 2      Estacion Migratoria INM  21.929551 -102.320223       PG472
# 3      Estacion Migratoria INM  19.845660  -90.539741       PG794
# 4  Centro de Atencion Integral  16.149934  -92.072111       PG737
# /Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3377: FutureWarning: The `op` parameter is deprecated and will be removed in a future release. Please use the `predicate` parameter instead.
#   if (await self.run_code(code, result,  async_=asy)):

# %%
# Realizar el merge (unión) entre datos_csv2 y grid usando 'ID_Poligono' como clave
df = df.merge(grid[['ID_Poligono', 'geometry']], on='ID_Poligono', how='left')

# %% [markdown]
# guardamos

# %%
ruta_nueva2 = '/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/3. mapas/1. Mapas/Metodo_1/ciudades_rutas/estaciones INM/inm_gdp.csv'

# Guardar el DataFrame en un archivo Excel en la ruta especificada
df.to_csv(ruta_nueva2, index=False)

print(f"El DataFrame ha sido guardado exitosamente en: {ruta_nueva2}")
# Out:
# El DataFrame ha sido guardado exitosamente en: /Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/3. mapas/1. Mapas/Metodo_1/ciudades_rutas/estaciones INM/inm_gdp.csv

# %%
ruta_archivo1 = '/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/3. mapas/1. Mapas/Metodo_1/ciudades_rutas/estaciones INM/inm_gdp.csv'

# Cargar el archivo .xls en un DataFrame
df1 = pd.read_csv(ruta_archivo1)

# %%
df1
# Out:
#                                                  name tipo  \
# 0                        Acayucan Estacion Migratoria  INM
# 1                    Agua Prieta Estacion Provisional  INM
# 2                  Aguascalientes Estacion Migratoria  INM
# 3                       Campeche Estacion Provisional  INM
# 4   Centro de Atencion Integral al Trafico Fronter...  INM
# 5   Centro de Atencion Integral al Transito Fronte...  INM
# 6                        Chetumal Estacion Migratoria  INM
# 7                       Chihuahua Estacion Migratoria  INM
# 8              Ciudad Cuauhtemoc Estacion Provisional  INM
# 9              Ciudad del Carmen Estacion Provisional  INM
# 10                  Ciudad Juarez Estacion Migratoria  INM
# 11                        Colima Estancia Provisional  INM
# 12                       Comitan Estacion Provisional  INM
# 13                     Echegaray Estacion Provisional  INM
# 14                      El Ceibo Estacion Provisional  INM
# 15                    El Hueyate Estacion Provisional  INM
# 16                      Escarcega Estacion Migratoria  INM
# 17                   Guadalajara Estacion Provisional  INM
# 18                     Hermosillo Estacion Migratoria  INM
# 19                      Huatulco Estancia Provisional  INM
# 20                     Huehuetan Estacion Provisional  INM
# 21  Iztapalapa Estacion Migratoria (Estacion Migra...  INM
# 22                          Janos Estacion Migratoria  INM
# 23                    La Ventosa Estacion Provisional  INM
# 24                      Matamoros Estacion Migratoria  INM
# 25                       Mazatlan Estacion Migratoria  INM
# 26                         Merida Estacion Migratoria  INM
# 27                       Mexicali Estacion Migratoria  INM
# 28                 Miguel Aleman Estacion Provisional  INM
# 29                     Monterrey Estacion Provisional  INM
# 30                   Nuevo Laredo Estacion Migratoria  INM
# 31                         Oaxaca Estacion Migratoria  INM
# 32                        Pachuca Estacion Migratoria  INM
# 33                       Palenque Estacion Migratoria  INM
# 34                Piedras Negras Estacion Provisional  INM
# 35            Playas de Catazaja Estacion Provisional  INM
# 36                         Puebla Estacion Migratoria  INM
# 37                       Saltillo Estacion Migratoria  INM
# 38    San Cristobal de las Casas Estacion Provisional  INM
# 39           San Gregorio Chamic Estacion Provisional  INM
# 40                San Luis Potosi Estacion Migratoria  INM
# 41         San Pedro Tapanatepec Estacion Provisional  INM
# 42                        Tampico Estacion Migratoria  INM
# 43          Tapachula Estacion Migratoria (Siglo XXI)  INM
# 44                      Tenosique Estacion Migratoria  INM
# 45                        Tijuana Estacion Migratoria  INM
# 46                       Tlaxcala Estacion Migratoria  INM
# 47                       Torreon Estacion Provisional  INM
# 48               Tuxtla Gutierrez Estacion Migratoria  INM
# 49                       Veracruz Estacion Migratoria  INM
# 50                   Villahermosa Estacion Migratoria  INM
# 51                      Zacatecas Estacion Migratoria  INM
# 52                    Zihuatanejo Estacion Migratoria  INM
#
#                        sub_tipo    latitud    longitud ID_Poligono  \
# 0       Estacion Migratoria INM  18.001851  -94.921076       PG685
# 1       Estacion Migratoria INM  31.332947 -109.560374       PG293
# 2       Estacion Migratoria INM  21.929551 -102.320223       PG472
# 3       Estacion Migratoria INM  19.845660  -90.539741       PG794
# 4   Centro de Atencion Integral  16.149934  -92.072111       PG737
# 5   Centro de Atencion Integral  15.162749  -92.532987       PG736
# 6       Estacion Migratoria INM  18.526295  -88.283332       PG847
# 7       Estacion Migratoria INM  28.642257 -106.084403       PG371
# 8       Estacion Migratoria INM  15.667668  -92.002344       PG736
# 9       Estacion Migratoria INM  18.642626  -91.823607       PG766
# 10      Estacion Migratoria INM  31.745586 -106.483964       PG374
# 11      Estacion Migratoria INM  18.526295  -88.283332       PG847
# 12      Estacion Migratoria INM  16.214324  -92.115576       PG737
# 13      Estacion Migratoria INM  15.654755  -93.149776       PG709
# 14      Estacion Migratoria INM  17.260287  -90.988373       PG792
# 15      Estacion Migratoria INM  15.160568  -92.515785       PG736
# 16      Estacion Migratoria INM  18.606645  -90.739388       PG793
# 17      Estacion Migratoria INM  20.726967 -103.345063       PG444
# 18      Estacion Migratoria INM  29.079571 -110.955262       PG264
# 19      Estacion Migratoria INM  15.827777  -96.320882       PG628
# 20      Estacion Migratoria INM  15.019603  -92.393178       PG736
# 21      Estacion Migratoria INM  19.316469  -99.083204       PG551
# 22      Estacion Migratoria INM  30.884843 -108.194389       PG319
# 23      Estacion Migratoria INM  16.548342  -94.948654       PG683
# 24      Estacion Migratoria INM  25.890848  -97.503147       PG611
# 25      Estacion Migratoria INM  23.192815 -106.419690       PG366
# 26      Estacion Migratoria INM  20.987216  -89.627130       PG822
# 27      Estacion Migratoria INM  32.585847 -115.438939       PG132
# 28      Estacion Migratoria INM  26.397943  -99.030118       PG558
# 29      Estacion Migratoria INM  25.642726 -100.318737       PG530
# 30      Estacion Migratoria INM  27.498089  -99.507208       PG559
# 31      Estacion Migratoria INM  17.061349  -96.722313       PG630
# 32      Estacion Migratoria INM  20.084752  -98.759365       PG579
# 33      Estacion Migratoria INM  17.494729  -91.986122       PG765
# 34      Estacion Migratoria INM  28.680380 -100.573504       PG533
# 35      Estacion Migratoria INM  17.721218  -92.015991       PG738
# 36      Estacion Migratoria INM  19.059846  -98.227322       PG578
# 37      Estacion Migratoria INM  25.422443 -100.944786       PG530
# 38      Estacion Migratoria INM  16.734462  -92.649164       PG737
# 39      Estacion Migratoria INM  15.680229  -92.005692       PG736
# 40      Estacion Migratoria INM  22.143597 -100.997765       PG527
# 41      Estacion Migratoria INM  16.369762  -94.192357       PG683
# 42      Estacion Migratoria INM  22.263194  -97.795803       PG608
# 43      Estacion Migratoria INM  14.920195  -92.259107       PG735
# 44      Estacion Migratoria INM  17.457765  -91.445217       PG765
# 45      Estacion Migratoria INM  32.471301 -117.013686        PG78
# 46      Estacion Migratoria INM  19.336626  -98.193398       PG578
# 47      Estacion Migratoria INM  25.538859 -103.453354       PG449
# 48      Estacion Migratoria INM  16.753920  -93.105268       PG710
# 49      Estacion Migratoria INM  19.199485  -96.140113       PG632
# 50      Estacion Migratoria INM  17.989956  -92.942932       PG738
# 51      Estacion Migratoria INM  22.765814 -102.578058       PG473
# 52      Estacion Migratoria INM  17.644247 -101.553969       PG495
#
#                                              geometry
# 0   POLYGON ((-95 19, -94 19, -94 18, -95 18, -95 ...
# 1   POLYGON ((-110 32, -109 32, -109 31, -110 31, ...
# 2   POLYGON ((-103 22, -102 22, -102 21, -103 21, ...
# 3   POLYGON ((-91 20, -90 20, -90 19, -91 19, -91 ...
# 4   POLYGON ((-93 17, -92 17, -92 16, -93 16, -93 ...
# 5   POLYGON ((-93 16, -92 16, -92 15, -93 15, -93 ...
# 6   POLYGON ((-89 19, -88 19, -88 18, -89 18, -89 ...
# 7   POLYGON ((-107 29, -106 29, -106 28, -107 28, ...
# 8   POLYGON ((-93 16, -92 16, -92 15, -93 15, -93 ...
# 9   POLYGON ((-92 19, -91 19, -91 18, -92 18, -92 ...
# 10  POLYGON ((-107 32, -106 32, -106 31, -107 31, ...
# 11  POLYGON ((-89 19, -88 19, -88 18, -89 18, -89 ...
# 12  POLYGON ((-93 17, -92 17, -92 16, -93 16, -93 ...
# 13  POLYGON ((-94 16, -93 16, -93 15, -94 15, -94 ...
# 14  POLYGON ((-91 18, -90 18, -90 17, -91 17, -91 ...
# 15  POLYGON ((-93 16, -92 16, -92 15, -93 15, -93 ...
# 16  POLYGON ((-91 19, -90 19, -90 18, -91 18, -91 ...
# 17  POLYGON ((-104 21, -103 21, -103 20, -104 20, ...
# 18  POLYGON ((-111 30, -110 30, -110 29, -111 29, ...
# 19  POLYGON ((-97 16, -96 16, -96 15, -97 15, -97 ...
# 20  POLYGON ((-93 16, -92 16, -92 15, -93 15, -93 ...
# 21  POLYGON ((-100 20, -99 20, -99 19, -100 19, -1...
# 22  POLYGON ((-109 31, -108 31, -108 30, -109 30, ...
# 23  POLYGON ((-95 17, -94 17, -94 16, -95 16, -95 ...
# 24  POLYGON ((-98 26, -97 26, -97 25, -98 25, -98 ...
# 25  POLYGON ((-107 24, -106 24, -106 23, -107 23, ...
# 26  POLYGON ((-90 21, -89 21, -89 20, -90 20, -90 ...
# 27  POLYGON ((-116 33, -115 33, -115 32, -116 32, ...
# 28  POLYGON ((-100 27, -99 27, -99 26, -100 26, -1...
# 29  POLYGON ((-101 26, -100 26, -100 25, -101 25, ...
# 30  POLYGON ((-100 28, -99 28, -99 27, -100 27, -1...
# 31  POLYGON ((-97 18, -96 18, -96 17, -97 17, -97 ...
# 32  POLYGON ((-99 21, -98 21, -98 20, -99 20, -99 ...
# 33  POLYGON ((-92 18, -91 18, -91 17, -92 17, -92 ...
# 34  POLYGON ((-101 29, -100 29, -100 28, -101 28, ...
# 35  POLYGON ((-93 18, -92 18, -92 17, -93 17, -93 ...
# 36  POLYGON ((-99 20, -98 20, -98 19, -99 19, -99 ...
# 37  POLYGON ((-101 26, -100 26, -100 25, -101 25, ...
# 38  POLYGON ((-93 17, -92 17, -92 16, -93 16, -93 ...
# 39  POLYGON ((-93 16, -92 16, -92 15, -93 15, -93 ...
# 40  POLYGON ((-101 23, -100 23, -100 22, -101 22, ...
# 41  POLYGON ((-95 17, -94 17, -94 16, -95 16, -95 ...
# 42  POLYGON ((-98 23, -97 23, -97 22, -98 22, -98 ...
# 43  POLYGON ((-93 15, -92 15, -92 14, -93 14, -93 ...
# 44  POLYGON ((-92 18, -91 18, -91 17, -92 17, -92 ...
# 45  POLYGON ((-118 33, -117 33, -117 32, -118 32, ...
# 46  POLYGON ((-99 20, -98 20, -98 19, -99 19, -99 ...
# 47  POLYGON ((-104 26, -103 26, -103 25, -104 25, ...
# 48  POLYGON ((-94 17, -93 17, -93 16, -94 16, -94 ...
# 49  POLYGON ((-97 20, -96 20, -96 19, -97 19, -97 ...
# 50  POLYGON ((-93 18, -92 18, -92 17, -93 17, -93 ...
# 51  POLYGON ((-103 23, -102 23, -102 22, -103 22, ...
# 52  POLYGON ((-102 18, -101 18, -101 17, -102 17, ...

# %%
# Eliminar la columna 'geometry'
df1 = df1.drop(columns=['geometry'])

# Verificar el resultado mostrando las primeras filas del DataFrame
print(df1.head())
# Out:
#                                                 name tipo  \
# 0                       Acayucan Estacion Migratoria  INM
# 1                   Agua Prieta Estacion Provisional  INM
# 2                 Aguascalientes Estacion Migratoria  INM
# 3                      Campeche Estacion Provisional  INM
# 4  Centro de Atencion Integral al Trafico Fronter...  INM
#
#                       sub_tipo    latitud    longitud ID_Poligono
# 0      Estacion Migratoria INM  18.001851  -94.921076       PG685
# 1      Estacion Migratoria INM  31.332947 -109.560374       PG293
# 2      Estacion Migratoria INM  21.929551 -102.320223       PG472
# 3      Estacion Migratoria INM  19.845660  -90.539741       PG794
# 4  Centro de Atencion Integral  16.149934  -92.072111       PG737

# %%
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import pandas as pd

# Usar RateLimiter para evitar sobrepasar el límite de peticiones al servicio de Nominatim
geocode = RateLimiter(geolocator.reverse, min_delay_seconds=1, error_wait_seconds=10)

# Inicializar Nominatim API
geolocator = Photon(user_agent="geopelavakas")

# Usar RateLimiter para evitar sobrepasar el límite de peticiones al servicio de Nominatim
geocode = RateLimiter(geolocator.reverse, min_delay_seconds=1)

# Definir una función para la geocodificación inversa
def obtener_ubicacion(fila):
    try:
        ubicacion = geocode((fila['latitud'], fila['longitud']), language='es')
        if ubicacion:
            ciudad = ubicacion.raw.get('address', {}).get('city', '')
            estado = ubicacion.raw.get('address', {}).get('state', '')
            return pd.Series([ciudad, estado])
        else:
            return pd.Series(['', ''])
    except:
        return pd.Series(['', ''])

# Crear nuevas columnas 'ciudad' y 'estado' en df1 aplicando la función de geocodificación inversa
df1[['ciudad', 'estado']] = df1.apply(obtener_ubicacion, axis=1)

# Verificar los resultados
print(df1[['latitud', 'longitud', 'ciudad', 'estado']].head())
# Out:
# RateLimiter caught an error, retrying (0/2 tries). Called with (*((18.00185138, -94.9210765),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (1/2 tries). Called with (*((18.00185138, -94.9210765),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter swallowed an error after 2 retries. Called with (*((18.00185138, -94.9210765),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (0/2 tries). Called with (*((31.33294658, -109.560374),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (1/2 tries). Called with (*((31.33294658, -109.560374),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter swallowed an error after 2 retries. Called with (*((31.33294658, -109.560374),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (0/2 tries). Called with (*((21.92955053, -102.3202229),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (1/2 tries). Called with (*((21.92955053, -102.3202229),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter swallowed an error after 2 retries. Called with (*((21.92955053, -102.3202229),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (0/2 tries). Called with (*((19.84566009, -90.53974092),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (1/2 tries). Called with (*((19.84566009, -90.53974092),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter swallowed an error after 2 retries. Called with (*((19.84566009, -90.53974092),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (0/2 tries). Called with (*((16.14993427, -92.07211098),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (1/2 tries). Called with (*((16.14993427, -92.07211098),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter swallowed an error after 2 retries. Called with (*((16.14993427, -92.07211098),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (0/2 tries). Called with (*((15.16274927, -92.53298711),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (1/2 tries). Called with (*((15.16274927, -92.53298711),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter swallowed an error after 2 retries. Called with (*((15.16274927, -92.53298711),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (0/2 tries). Called with (*((18.5262955, -88.2833324),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (1/2 tries). Called with (*((18.5262955, -88.2833324),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter swallowed an error after 2 retries. Called with (*((18.5262955, -88.2833324),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (0/2 tries). Called with (*((28.64225733, -106.0844028),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (1/2 tries). Called with (*((28.64225733, -106.0844028),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter swallowed an error after 2 retries. Called with (*((28.64225733, -106.0844028),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (0/2 tries). Called with (*((15.66766816, -92.00234413),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (1/2 tries). Called with (*((15.66766816, -92.00234413),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter swallowed an error after 2 retries. Called with (*((15.66766816, -92.00234413),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (0/2 tries). Called with (*((18.64262612, -91.82360709),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (1/2 tries). Called with (*((18.64262612, -91.82360709),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
# ...
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (0/2 tries). Called with (*((17.9899559, -92.9429324),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (1/2 tries). Called with (*((17.9899559, -92.9429324),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter swallowed an error after 2 retries. Called with (*((17.9899559, -92.9429324),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (0/2 tries). Called with (*((22.76581404, -102.5780582),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (1/2 tries). Called with (*((22.76581404, -102.5780582),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter swallowed an error after 2 retries. Called with (*((22.76581404, -102.5780582),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (0/2 tries). Called with (*((17.64424696, -101.5539694),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter caught an error, retrying (1/2 tries). Called with (*((17.64424696, -101.5539694),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 136, in _retries_gen
#     yield i  # Run the function.
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
# RateLimiter swallowed an error after 2 retries. Called with (*((17.64424696, -101.5539694),), **{'language': 'es'}).
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 368, in _call_geocoder
#     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 447, in get_json
#     resp = self._request(url, timeout=timeout, headers=headers)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/adapters.py", line 475, in _request
#     raise AdapterHTTPError(
# geopy.adapters.AdapterHTTPError: Non-successful status code 400
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/extra/rate_limiter.py", line 274, in __call__
#     res = self.func(*args, **kwargs)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/photon.py", line 218, in reverse
#     return self._call_geocoder(url, callback, timeout=timeout)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 388, in _call_geocoder
#     res = self._adapter_error_handler(error)
#   File "/Users/pablouriarte/opt/anaconda3/lib/python3.9/site-packages/geopy/geocoders/base.py", line 411, in _adapter_error_handler
#     raise exc_cls(str(error)) from error
# geopy.exc.GeocoderQueryError: Non-successful status code 400
#      latitud    longitud ciudad estado
# 0  18.001851  -94.921076
# 1  31.332947 -109.560374
# 2  21.929551 -102.320223
# 3  19.845660  -90.539741
# 4  16.149934  -92.072111

# %%
df1['ciudad'].unique()
# Out:
# array([''], dtype=object)

# %% [markdown]
# ## CBP Entry Ports Data
#
# The directory of the entry ports in the CBP jurisdiction includes terrestrial ports, maritimal ports and airpoirts of the southwest landborder.
#
# df_CA = https://www.cbp.gov/about/contact/ports/ca
#
# df_AZ = https://www.cbp.gov/about/contact/ports/az
#
# df_nm = https://www.cbp.gov/about/contact/ports/nm
#
# df_tx = https://www.cbp.gov/about/contact/ports/tx

# %%
from bs4 import BeautifulSoup

import requests
import re

import pandas as pd

from geopy.geocoders import Photon
from geopy.geocoders import Nominatim

# %% [markdown]
# ## All entries
# ### Step 1: Data Scrap

# %%
# URLs and their corresponding state abbreviations
urls = {
    'ca': 'https://www.cbp.gov/about/contact/ports/ca',
    'az': 'https://www.cbp.gov/about/contact/ports/az',
    'nm': 'https://www.cbp.gov/about/contact/ports/nm',
    'tx': 'https://www.cbp.gov/about/contact/ports/tx'
}

# Function to scrape and create a DataFrame from a given URL
def scrape_to_df(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    table = soup.find('table')
    data = []
    for row in table.find_all('tr'):
        cols = row.find_all('td')
        if len(cols) > 0:
            col_data = [ele.text.strip().replace('\n', ' ') for ele in cols]
            data.append(col_data)
    return pd.DataFrame(data, columns=['Port Name', 'Location Address', 'Field Operation Office'])

# Dictionary to hold each state's DataFrame
state_dfs = {}

# Scrape each URL and store the resulting DataFrame
for state_abbr, url in urls.items():
    df_temp = scrape_to_df(url)
    # Add a state column to each DataFrame
    df_temp['State'] = state_abbr.upper()
    state_dfs[f'df_{state_abbr}'] = df_temp

# Merge all state DataFrames into df_sb_all
df_sb_all = pd.concat(state_dfs.values(), ignore_index=True)

# %%
#Take out the airports
#Otra opcion podria ser quitar por CP, hacer una lista de cp que aplican y quitar los demas

# %%
# Filtrar el DataFrame para excluir filas que contienen la palabra "airport"
#df_sb_all = df_sb_all[~df_sb_all.apply(lambda x: x.astype(str).str.contains('airport', case=False, na=False)).any(axis=1)]

# %%
num_filas = df_sb_all.shape[0]
print(f"El número total de líneas (filas) es: {num_filas}")
# Out:
# El número total de líneas (filas) es: 47

# %%
#revisar nones

# %% [markdown]
#  ### CBP Entry Ports
#  #### Step 2: Get Geolocate Addresses to Coords

# %%
# Inicializar el geolocalizador de Photon
geolocator = Photon(user_agent="geoapiExercises")

# Función para obtener latitud y longitud
def get_lat_long(address):
    try:
        location = geolocator.geocode(address)
        if location:
            return (location.latitude, location.longitude)
        else:
            return (None, None)
    except:
        return (None, None)

# Aplicar la función a la columna 'Location Address'
df_sb_all['Coordinates'] = df_sb_all['Location Address'].apply(lambda x: get_lat_long(x))

# Separar las coordenadas en dos columnas nuevas: 'Latitude' y 'Longitude'
df_sb_all[['Latitude', 'Longitude']] = pd.DataFrame(df_sb_all['Coordinates'].tolist(), index=df_sb_all.index)

# %%
df_sb_all.head(70)
# Out:
#                                             Port Name  \
# 0                Andrade - Class A, California - 2502
# 1          Calexico East - Class A, California - 2507
# 2          Calexico West - Class A, California - 2503
# 3                           Eureka, California - 2802
# 4               Fresno (2803/2882), California - 2803
# 6   Los Angeles/Long Beach Seaport, California - 2704
# 8                        Otay Mesa, California - 2506
# 9                     Palm Springs, California - 2781
# 10                    Port Hueneme, California - 2713
# 13                       San Diego, California - 2501
# 15                   San Francisco, California - 2809
# 17            San Ysidro - Class A, California - 2504
# 18                Tecate - Class A, California - 2505
# 20                            Douglas, Arizona - 2601
# 21                          Lukeville, Arizona - 2602
# 22                               Naco, Arizona - 2603
# 23                            Nogales, Arizona - 2604
# 24                            Phoenix, Arizona - 2605
# 26                           San Luis, Arizona - 2608
# 27                             Sasabe, Arizona - 2606
# 29                             Tucson, Arizona - 2609
# 30                     Albuquerque, New Mexico - 2407
# 31                        Columbus, New Mexico - 2406
# 32                    Santa Teresa, New Mexico - 2408
# 36                               Austin, Texas - 5506
# 37                          Brownsville, Texas - 2301
# 38                               Conroe, Texas - 5382
# 39                       Corpus Christi, Texas - 5312
# 40                     Dallas/Ft. Worth, Texas - 5501
# 41                              Del Rio, Texas - 2302
# 42                           Eagle Pass, Texas - 2303
# 43                              El Paso, Texas - 2402
# 44                             Freeport, Texas - 5311
# 46                              Hidalgo, Texas - 2305
# 48                      Houston Seaport, Texas - 5301
# 49                               Laredo, Texas - 2304
# 51                             McKinney, Texas - 5585
# 53                 Port Arthur-Beaumont, Texas - 2101
# 54            Port Lavaca-Point Comfort, Texas - 5313
# 55                             Presidio, Texas - 2403
# 56                             Progreso, Texas - 2309
# 57                      Rio Grande City, Texas - 2307
# 58                                 Roma, Texas - 2310
# 59                               Sabine, Texas - 2102
# 62                            Sugarland, Texas - 5381
# 63                             Tornillo, Texas - 2404
# 64                      Ysleta, El Paso, Texas - 2401
#
#                                      Location Address Field Operation Office  \
# 0   235 Andrade Road Winterhaven, CA 92283 United ...              San Diego
# 1   1699 East Carr, Rd Bldg A Calexico, CA 92231 U...              San Diego
# 2   200 East First Street Calexico, CA 92231 Unite...              San Diego
# 3   317 3rd Street, Suite 6 Eureka, CA 95501 Unite...          San Francisco
# 4   5177 E. Clinton Way Fresno, CA 93727 United St...          San Francisco
# 6   301 E. Ocean Blvd. Suite 1400 Long Beach, CA 9...            Los Angeles
# 8   9777 Via De La Amistad San Diego, CA 92154 Uni...              San Diego
# 9   210 N. El Cielo Road Palm Springs, CA 92262 Un...            Los Angeles
# 10  720 W. Hueneme Road Oxnard, CA 93033 United St...            Los Angeles
# 13  3835 N. Harbor Drive Terminal 2 West San Diego...              San Diego
# 15  555 Battery Street, Room 319 San Francisco, CA...          San Francisco
# 17  720 East San Ysidro Blvd San Ysidro, CA 92173 ...              San Diego
# 18       405 Tecate Rd Tecate, CA 91980 United States              San Diego
# 20  First Street and Pan American Avenue Douglas, ...                 Tucson
# 21  Highway 85 & Border Lukeville, AZ 85341 United...                 Tucson
# 22  3867 S. Towner Avenue Naco, AZ 85620 United St...                 Tucson
# 23  9 North Grand Ave. Nogales, AZ 85621 United St...                 Tucson
# 24  3002 E. Old Tower Road, Suite 400 Phoenix, AZ ...                 Tucson
# 26  Highway 95 & International Border San Luis, AZ...                 Tucson
# 27  Highway 286 and International Border Sasabe, A...                 Tucson
# 29  7081 South Plumer Ave Tucson, AZ 85756 United ...                 Tucson
# 30  2200 Sunport Blvd. SE Albuquerque, NM 87106 Un...                El Paso
# 31  State Highway 11 Mile Marker 0 Columbus, NM 88...                El Paso
# 32  170 Pete Domenici Hwy PO Box1439 Santa Teresa,...                El Paso
# 36  3600 Presidential Blvd. Ste. 111 Austin, TX 78...                Houston
# 37  3300 S. Expressway77/83 Brownsville, TX 78521 ...                 Laredo
# 38  2975 Hawthorne Drive Conroe, TX 77303 United S...                Houston
# 39  9149 State Highway 44 Corpus Christi, TX 78406...                Houston
# 40  7501 Esters Blvd.,Suite 160 Irving, TX 75063 U...                Houston
# 41  3140 Spur 239 International Bridge Del Rio, TX...                 Laredo
# 42  160 Garrison St. Eagle Pass, TX 78852 United S...                 Laredo
# 43  Bridge of the Americas Port of Entry 3600 E. P...                El Paso
# 44  801 Navigation P.O. Box 2740 Freeport, TX 7754...                Houston
# 46  9901 S. Cage Boulevard Suite B Pharr, TX 78577...                 Laredo
# 48  7141 Office City Drive Houston, TX 77087 Unite...                Houston
# 49  Lincoln/Juarez Bridge, Administrative Bldg. #2...                 Laredo
# 51  1500 E. Industrial Blvd Mckinney, TX 75069 Uni...                Houston
# 53  4550 Jimmy Johnson Blvd Suite 1 Port Arthur, T...                Houston
# 54  9149 State Highway 44 Corpus Christi, TX 78406...                Houston
# 55  Border Station Highway 67 PO Box 1959 Presidio...                El Paso
# 56  100 South International Boulevard Progreso, TX...                 Laredo
# 57  317 S. Pete Diaz Ave. Rio Grande City, TX 7858...                 Laredo
# 58  405 N. Estrella St., Suite B Roma, TX 78584 Un...                 Laredo
# 59  4550 Jimmy Johnson Blvd Pt Arthur, TX 77642 Un...                Houston
# 62  12888 Highway 6 South Sugar Land, TX 77478 Uni...                Houston
# 63  1400 Lower Island Rd. (FM 1109) Tornillo, TX 7...                El Paso
# 64  797 S. Zaragosa Rd. El Paso, TX 79907 United S...                El Paso
#
#    State                                Coordinates   Latitude   Longitude
# 0     CA                  (32.7184216, -114.727919)  32.718422 -114.727919
# 1     CA                 (32.6753413, -115.3887997)  32.675341 -115.388800
# 2     CA    (38.88981295000001, -77.00902077737487)  38.889813  -77.009021
# 3     CA          (40.8035929, -124.16821893938675)  40.803593 -124.168219
# 4     CA                 (36.7722997, -119.7316224)  36.772300 -119.731622
# 6     CA         (33.76468345, -118.19082874479344)  33.764683 -118.190829
# 8     CA                 (32.5518614, -116.9357264)  32.551861 -116.935726
# 9     CA                 (33.8248194, -116.5147028)  33.824819 -116.514703
# 10    CA         (34.20009175, -119.20789455598106)  34.200092 -119.207895
# 13    CA                 (32.7289725, -117.1856172)  32.728972 -117.185617
# 15    CA          (37.7962856, -122.40091595368713)  37.796286 -122.400916
# 17    CA                 (32.5520013, -117.0430813)  32.552001 -117.043081
# 18    CA                 (32.5833711, -116.6285217)  32.583371 -116.628522
# 20    AZ                               (None, None)        NaN         NaN
# 21    AZ                 (31.8802588, -112.8173538)  31.880259 -112.817354
# 22    AZ                 (31.3416145, -109.9484614)  31.341614 -109.948461
# 23    AZ                   (31.381221, -110.692119)  31.381221 -110.692119
# 24    AZ         (33.42456835, -112.01580555000001)  33.424568 -112.015806
# 26    AZ                               (None, None)        NaN         NaN
# 27    AZ                               (None, None)        NaN         NaN
# 29    AZ                 (32.1230115, -110.9422136)  32.123011 -110.942214
# 30    NM  (35.037669449999996, -106.61096752176844)  35.037669 -106.610968
# 31    NM                 (39.7819444, -105.4627778)  39.781944 -105.462778
# 32    NM                               (None, None)        NaN         NaN
# 36    TX          (30.19348925, -97.66500963529677)  30.193489  -97.665010
# 37    TX          (25.88944605, -97.47524006903629)  25.889446  -97.475240
# 38    TX                  (30.3366003, -95.4278639)  30.336600  -95.427864
# 39    TX           (27.7795634, -97.54368974041131)  27.779563  -97.543690
# 40    TX           (32.9156845, -97.01981860699152)  32.915684  -97.019819
# 41    TX                               (None, None)        NaN         NaN
# 42    TX                  (28.7083999, -100.503941)  28.708400 -100.503941
# 43    TX                 (31.7655247, -106.4508619)  31.765525 -106.450862
# 44    TX                               (None, None)        NaN         NaN
# 46    TX                   (26.150465, -98.1915069)  26.150465  -98.191507
# 48    TX   (29.701226300000002, -95.29118798338997)  29.701226  -95.291188
# 49    TX                               (None, None)        NaN         NaN
# 51    TX           (33.1749285, -96.63743685567803)  33.174929  -96.637437
# 53    TX                               (None, None)        NaN         NaN
# 54    TX           (27.7795634, -97.54368974041131)  27.779563  -97.543690
# 55    TX                               (None, None)        NaN         NaN
# 56    TX          (32.97218925, -96.33837973785512)  32.972189  -96.338380
# 57    TX                  (26.3662687, -98.8019061)  26.366269  -98.801906
# 58    TX           (29.5607161, -98.39325727203885)  29.560716  -98.393257
# 59    TX                               (None, None)        NaN         NaN
# 62    TX          (29.62238065, -95.65551923937042)  29.622381  -95.655519
# 63    TX                               (None, None)        NaN         NaN
# 64    TX                  (31.7573731, -106.495919)  31.757373 -106.495919

# %%
#guardar el archivo CSV
path = "/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/1. distribution_Institucional/3. CBP Entry Ports/cbp_entry_ports_loc.csv"

# Guardar el DataFrame como CSV
df_sb_all.to_csv(path, index=False)

print("Archivo guardado exitosamente en:", path)
# Out:
# Archivo guardado exitosamente en: /Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/1. distribution_Institucional/3. CBP Entry Ports/cbp_entry_ports_loc.csv

# %% [markdown]
# ### Terrestrial Port Entries
#
# https://en.wikipedia.org/wiki/List_of_Mexico%E2%80%93United_States_border_crossings

# %%
import pandas as pd

# Reemplaza 'tu_ruta_al_archivo.csv' con la ruta real de tu archivo CSV
ruta_archivo = '/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/1. distribution_infraestructura/3. CBP Entry Ports/mxusa_entry_ports_loc.csv'
df = pd.read_csv(ruta_archivo)

# %%
df.head()
# Out:
#             Name Code                Location  \
# 0     San Ysidro  SYS  San Ysidro, California
# 1      Otay Mesa  OTM   Otay Mesa, California
# 2         Tecate  TEC      Tecate, California
# 3  Calexico West  CAL    Calexico, California
# 4  Calexico East  IVP    Calexico, California
#
#                                Coordinates  Unnamed: 4  Unnamed: 5
# 0   32.54431071396611, -117.02856441126859         NaN         NaN
# 1  32.548830333720865, -116.93751776676132         NaN         NaN
# 2  32.576259490009384, -116.62745997805513         NaN         NaN
# 3                   32.665106, -115.496349         NaN         NaN
# 4   32.67541923014072, -115.38831102864438         NaN         NaN

# %%
# Dividir la columna 'Coordinates' en dos nuevas columnas 'Latitude' y 'Longitude'
df[['Latitude', 'Longitude']] = df['Coordinates'].str.split(',', expand=True)

# Convertir las nuevas columnas a tipo float para operaciones numéricas
df['Latitude'] = df['Latitude'].astype(float)
df['Longitude'] = df['Longitude'].astype(float)

# Mostrar las primeras filas del DataFrame para verificar las nuevas columnas
print(df.head())
# Out:
#             Name Code                Location  \
# 0     San Ysidro  SYS  San Ysidro, California
# 1      Otay Mesa  OTM   Otay Mesa, California
# 2         Tecate  TEC      Tecate, California
# 3  Calexico West  CAL    Calexico, California
# 4  Calexico East  IVP    Calexico, California
#
#                                Coordinates  Unnamed: 4  Unnamed: 5   Latitude  \
# 0   32.54431071396611, -117.02856441126859         NaN         NaN  32.544311
# 1  32.548830333720865, -116.93751776676132         NaN         NaN  32.548830
# 2  32.576259490009384, -116.62745997805513         NaN         NaN  32.576259
# 3                   32.665106, -115.496349         NaN         NaN  32.665106
# 4   32.67541923014072, -115.38831102864438         NaN         NaN  32.675419
#
#     Longitude
# 0 -117.028564
# 1 -116.937518
# 2 -116.627460
# 3 -115.496349
# 4 -115.388311

# %%
# Eliminar columnas específicas por nombre
df = df.drop(columns=['Unnamed: 4', 'Unnamed: 5'])

# Mostrar las primeras filas para verificar los cambios
print(df.head())
# Out:
#             Name Code                Location  \
# 0     San Ysidro  SYS  San Ysidro, California
# 1      Otay Mesa  OTM   Otay Mesa, California
# 2         Tecate  TEC      Tecate, California
# 3  Calexico West  CAL    Calexico, California
# 4  Calexico East  IVP    Calexico, California
#
#                                Coordinates   Latitude   Longitude
# 0   32.54431071396611, -117.02856441126859  32.544311 -117.028564
# 1  32.548830333720865, -116.93751776676132  32.548830 -116.937518
# 2  32.576259490009384, -116.62745997805513  32.576259 -116.627460
# 3                   32.665106, -115.496349  32.665106 -115.496349
# 4   32.67541923014072, -115.38831102864438  32.675419 -115.388311

# %%
# Especifica la misma ruta del archivo original
archivo_path = '/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/1. distribution_infraestructura/3. CBP Entry Ports/mxusa_entry_ports_loc.csv'

# Guardar el DataFrame actualizado en el archivo, sobrescribiendo el original
df.to_csv(archivo_path, index=False, encoding='utf-8')

print(f"Archivo actualizado guardado en: {archivo_path}")
# Out:
# Archivo actualizado guardado en: /Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/1. distribution_infraestructura/3. CBP Entry Ports/mxusa_entry_ports_loc.csv

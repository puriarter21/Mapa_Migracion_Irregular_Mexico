# %% [markdown]
# # Preparacion Instituciones (Coordenadas)
#
# En este notebook hacemos una verificacion final de las bases de datos de instituciones y coordenadas extraidas, este paso continua al procesamiento de GEOCODE.
#
#     1)Centralizar todas las bd
#     2)Separamos y tratamos manualmente todas las instituciones que salieron fuera de Mexico en el proceso de GEOCODE
#     3)Buscamos disminuir el ruido de instituciones repetidas entre diferentes bd, buscamos ubicaciones duplicadas de acuerdo a las siguientes condiciones:
#         1)Los primeros 5 digitos: ej. lat 18,555 o long -108,021 son iguales
#         y
#         2)La columna "descripcion" tiene la misma categoria,
#
# Una vez completados estos pasos, se obtendrá una base de datos con la presencia institucional de organizaciones gubernamentales, y de la sociedad civil que se ocupan de migrantes en tránsito irregular en territorio mexicano.

# %%
import pandas as pd  # Library for data manipulation and analysis

# %% [markdown]
# ## Cargar todos los documentos a la vez

# %%
# Para cargar 5.Oficinasdeatencionalmigrantesvalidado.csv
df1 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/bd_ubicacionesfinales/5.Oficinasdeatencionalmigrantesvalidado.csv', encoding='utf-8')

# Para cargar 17.comar
df2 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/bd_ubicacionesfinales/17.comar.csv', encoding='utf-8')

# Para cargar 14.cndh.csv
df3 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/bd_ubicacionesfinales/14.cndh.csv', encoding='utf-8')

# Para cargar 1.Redesvalidacion.csv
df4 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/bd_ubicacionesfinales/1.Redesvalidacion.csv', encoding='utf-8')

# Para cargar 7.aberguesdirecotorioonu
df5 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/bd_ubicacionesfinales/7.aberguesdirecotorioonu.csv', encoding='utf-8')

# Para cargar 2.agenciasonu.csv
df6 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/bd_ubicacionesfinales/2.agenciasonu.csv', encoding='utf-8')

# Para cargar 8.cruzroja
df7 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/bd_ubicacionesfinales/8.cruzroja.csv', encoding='utf-8')

# Para cargar 9.centrosasistenciasocial.csv
df8 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/bd_ubicacionesfinales/9.centrosasistenciasocial.csv', encoding='utf-8')

# Para cargar 10.fiscaliasmig.csv
df9 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/bd_ubicacionesfinales/10.fiscaliasmig.csv', encoding='utf-8')

# Para cargar 11.gruposbeta.csv
df10 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/bd_ubicacionesfinales/11.gruposbeta.csv', encoding='utf-8')

# Para cargar 12.instmujeres.csv
df11 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/bd_ubicacionesfinales/12.instmujeres.csv', encoding='utf-8')

# Para cargar 13.inm.csv
df12 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/bd_ubicacionesfinales/13.inm.csv', encoding='utf-8')

# Para cargar 15.consulados.csv
df13 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/bd_ubicacionesfinales/15.consulados.csv', encoding='utf-8')

# Para cargar 3.acnurserviciosvalidado.csv
df14 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/bd_ubicacionesfinales/3.acnurserviciosvalidado.csv', encoding='utf-8')

# Para cargar 4.acnuralberguesvalidado.csv
df15 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/bd_ubicacionesfinales/4.acnuralberguesvalidado.csv', encoding='utf-8')

# Para cargar 16.oficinasdif.csv
df16 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/bd_ubicacionesfinales/16.oficinasdif.csv', encoding='utf-8')

# %% [markdown]
# ## Notas
#
# Tratar individualmente cada una de las bd: despues volver a cargar estos pasos, recuerda que algunas

# %%
# Count the number of NaN values in the 'coordenadas' column
nan_count_coordenadas = df_centralized['coordenadas'].isna().sum()

# Display the count
print(f"The number of NaN values in the 'coordenadas' column is {nan_count_coordenadas}.")
# Out:
# The number of NaN values in the 'coordenadas' column is 0.

# %%
df_centralized.head(50)
# Out:
#                                                  name  \
# 0    Oficinas de Atención a Migrante - Aguascalientes
# 1   Oficinas de Atención a Migrante - Baja California
# 2         Oficinas de Atención a Migrante - Chihuahua
# 3          Oficinas de Atención a Migrante - Campeche
# 4           Oficinas de Atención a Migrante - Chiapas
# 5          Oficinas de Atención a Migrante - Coahuila
# 6            Oficinas de Atención a Migrante - Colima
# 7   Oficinas de Atención a Migrante - Ciudad de Mé...
# 8           Oficinas de Atención a Migrante - Durango
# 9   Oficinas de Atención a Migrante - Estado de Mé...
# 10         Oficinas de Atención a Migrante - Guerrero
# 11       Oficinas de Atención a Migrante - Guanajuato
# 12          Oficinas de Atención a Migrante - Hidalgo
# 13          Oficinas de Atención a Migrante - Jalisco
# 14        Oficinas de Atención a Migrante - Michoacán
# 15          Oficinas de Atención a Migrante - Morelos
# ...

# %%
#centralizamos todos los data frame

# Lista de todos los DataFrames
list_of_dfs = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16]

# Concatenar todos los DataFrames en uno solo
df_centralized = pd.concat(list_of_dfs, ignore_index=True)

# %%
#quitar primera fila
# Eliminar la primera fila
df_centralized = df_centralized.iloc[1:].reset_index(drop=True)

# %%
# Eliminar las columnas #'Teléfono', 'Correo electrónico', 'Telefono', 'Horarios' ,
df_centralized = df_centralized.drop(columns=['Teléfono', 'Correo electrónico', 'Telefono', 'Horarios' ,'estado'])

# %%
#hacemos un subdataframe por si nos equivocamos
coordenadas = df_centralized

# %%
#Quitar los parentesis de la columna coordenada

# Reemplaza los paréntesis '(' y ')' con una cadena vacía ''
coordenadas['coordenadas'] = coordenadas['coordenadas'].str.replace(r'\(|\)', '', regex=True)

# %%
#Redistribuimos las columans de latitud y longitud a partir de coordenadas.
# Dividir la columna 'coordenadas' en dos nuevas columnas 'latitud' y 'longitud'
df_centralized[['latitud', 'longitud']] = df_centralized['coordenadas'].str.split(',', expand=True)

# Convertir las nuevas columnas a tipo float, si es necesario
df_centralized['latitud'] = df_centralized['latitud'].astype(float)
df_centralized['longitud'] = df_centralized['longitud'].astype(float)

# %% [markdown]
# #####

# %%
coordenadas.head(50)
# Out:
#                                                  name  \
# 0    Oficinas de Atención a Migrante - Aguascalientes
# 1   Oficinas de Atención a Migrante - Baja California
# 2         Oficinas de Atención a Migrante - Chihuahua
# 3          Oficinas de Atención a Migrante - Campeche
# 4           Oficinas de Atención a Migrante - Chiapas
# 5          Oficinas de Atención a Migrante - Coahuila
# 6            Oficinas de Atención a Migrante - Colima
# 7   Oficinas de Atención a Migrante - Ciudad de Mé...
# 8           Oficinas de Atención a Migrante - Durango
# 9   Oficinas de Atención a Migrante - Estado de Mé...
# 10         Oficinas de Atención a Migrante - Guerrero
# 11       Oficinas de Atención a Migrante - Guanajuato
# 12          Oficinas de Atención a Migrante - Hidalgo
# 13          Oficinas de Atención a Migrante - Jalisco
# 14        Oficinas de Atención a Migrante - Michoacán
# 15          Oficinas de Atención a Migrante - Morelos
# ...

# %%
coordenadas.shape
# Out:
# (1397, 8)

# %%
# Save the DataFrame to the specified path with UTF-8 encoding
#coordenadas.to_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/institucionesmigracionfull.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Tratamos todas las instituciones que salen fuera de mexico,
# Ya deben de estar tratadas, simplemente asegurate que los csv de bd_ubicaciones finales sea consistente con el archivo final.

# %%
#coord = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/institucionesmigracionfull.csv', encoding='utf-8')

# %%
#coord['latitud'] = coord['latitud'].astype(float)
#coord['longitud'] = coord['longitud'].astype(float)

# %%
#coord.head()
# Out:
#                                                 name  \
# 0   Oficinas de Atención a Migrante - Aguascalientes
# 1  Oficinas de Atención a Migrante - Baja California
# 2        Oficinas de Atención a Migrante - Chihuahua
# 3         Oficinas de Atención a Migrante - Campeche
# 4          Oficinas de Atención a Migrante - Chiapas
#
#                        descripcion    latitud    longitud  \
# 0  Oficinas de Atención a Migrante  21.879263 -102.295572
# 1  Oficinas de Atención a Migrante  32.826762 -116.856910
# 2  Oficinas de Atención a Migrante  28.715916 -106.007013
# 3  Oficinas de Atención a Migrante  40.038858  -85.999840
# 4  Oficinas de Atención a Migrante  14.874316  -92.255495
#
#                  coordenadas tipo  \
# 0  21.87926327, -102.2955718  GOB
# 1  32.82676218, -116.8569095  GOB
# 2  28.71591621, -106.0070135  GOB
# 3   40.0388583, -85.99984032  GOB
# 4  14.87431631, -92.25549474  GOB
#
#                                            direccion  \
# ...

# %% [markdown]
# ### Paso 1: Crear un sub-dataframe con registros fuera del rang
#
# Arreglarlos manualmente en mi local

# %%
#coord_mx = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/institucionesmigracionfull.csv', encoding='utf-8')

# %%
coord_mx.shape
# Out:
# (1395, 9)

# %%
# Establecer los límites para latitud y longitud
lat_max = 32.69
lat_min = 14.79
long_max = -86.8
long_min = -117.1

# %%
# Crear un sub-dataframe con registros fuera del rango de coordenadas
#df_sub_out_of_range = coord_mx[
    (coord_mx['latitud'] > lat_max) | 
    (coord_mx['latitud'] < lat_min) | 
    (coord_mx['longitud'] > long_max) | 
    (coord_mx['longitud'] < long_min)
]

# Si deseas reiniciar el índice del sub-dataframe
#df_sub_out_of_range = df_sub_out_of_range.reset_index(drop=True)
#coord_mx = coord_mx.reset_index(drop=True)

# %%
df_sub_out_of_range.shape
# Out:
# (22, 9)

# %%
#descargar el sub dataframe
#df_sub_out_of_range.to_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/outofrange.csv', index=False, encoding='utf-8')

# %% [markdown]
# ### Paso 2: Eliminar esos registros del dataframe original

# %%
# Eliminar los registros antiguos del DataFrame original
#coord_mx = coord_mx.drop(df_sub_out_of_range.index)

# Resetear los índices del DataFrame original para evitar conflictos
#coord_mx = coord_mx.reset_index(drop=True)

# Concatenar el DataFrame modificado con el DataFrame original
#coord = pd.concat([coord, df_modificado], ignore_index=True)

# %% [markdown]
# ### Paso 3: Cargar el subdataframe arreglado y pegarlo de nuevo

# %%
#coord = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/institucionesmigracionfull.csv', encoding='utf-8')

# %%
coord.shape
# Out:
# (1395, 9)

# %%
#on_range = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/outofrange.csv', encoding='utf-8')

# %%
on_range.head(26)
# Out:
#                                                  name  \
# 0   Oficinas de Atención a Migrante - Baja California
# 1          Oficinas de Atención a Migrante - Campeche
# 2           Oficinas de Atención a Migrante - Jalisco
# 3            Oficinas de Atención a Migrante - Sonora
# 4                          COMAR - Tenosique, Tabasco
# 5     Defensoría de los Derechos Humanos de Querétaro
# 6                            SEMIGRANTE (Tlazazalca)
# 7                            INM Grupo Beta Mexicali
# 8                                        Juárez, A.C.
# 9                                        Madre Teresa
# 10                                           Nazareth
# 11                                               Amar
# 12                                Decanal Guadalupano
# 13  Centro de Asistencia Social de Niñas, Niños y ...
# 14                        Casa Hogar El Altísimo A.C.
# 15                                  Grupo Beta Tecate
# ...

# %%
# Lista de todos los DataFrames
#dfs = [coord, on_range]

# Concatenar todos los DataFrames en uno solo
coord_mx = pd.concat(dfs, ignore_index=True)

# %%
#coord_mx.shape
# Out:
# (1397, 9)

# %% [markdown]
# #### Volvemso a revisar por fueras de rango

# %%
# Establecer los límites para latitud y longitud
lat_max = 32.69
lat_min = 14.79
long_max = -86.8
long_min = -117.1

# %%
condition = (coord_mx['latitud'] >= lat_min) & (coord_mx['latitud'] <= lat_max) & (coord_mx['longitud'] >= long_min) & (coord_mx['longitud'] <= long_max)
coord_mx = coord_mx[condition]

# %%
#ordenar por latitud
coord_mx = coord_mx.sort_values('latitud', ascending=False)

# %%
#Actualizamos el documento de nuevo.
#coord_mx.to_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/institucionesmigracionfull.csv', encoding='utf-8')

# %% [markdown]
# # Tratamos ubicaciones repetidas
#
# Que no cumpla las dos condiciones al mismo tiempo, Si:
#
#     1)Los primeros 3 digitos decimales: ej. lat 18,555 o long -108,021 son iguales
#     y
#     2)La columna "descripcion" tiene la misma categoria,
# Entonces:
#     Removemos de la base cualquier resultado adicional salvo el primero

# %%
#coord_tr = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/institucionesmigracionfull.csv', encoding='utf-8')

# %%
coord_tr.head(50)
# Out:
#                                                  name  \
# 0                         DIF Estatal Baja California
# 1                               Ángeles Sin Fronteras
# 2                Centro de Apoyo al Trabajor Migrante
# 3    Centro de Apoyo al Trabajador Migrante: Comit...
# 4                                 Comedor Cobina A.C.
# 5                               Comedor Cobina, A.C.
# 6                                 Juntos en el Camino
# 7                                      HIAS Mexicali
# 8                      Dispensario Médico Dr. Cañedo
# 9    Grupo de Ayuda para el Migrante de Mexicali A...
# 10  Grupo de Ayuda para el Migrante de Mexicali, A.C.
# 11                               Juvenil del Desierto
# 12                                 El Buen Samaritano
# 13   Centro de Reintegración Familiar de Menores M...
# 14                           Mana de Mexicali, I.B.P.
# 15   Cáritas Región Mexicali, A.C. El Buen Samarit...
# ...

# %%
#Se crearon columnas adicionales, las eliminamos.
coord_tr = coord_tr.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'])

# %%
#Normalizamos categorias
# Reemplazar los valores en la columna 'descripcion'
coord_tr['descripcion'] = coord_tr['descripcion'].replace({
    'Centros de Asistencia Social': 'Centros de Atención Social',
    'Centros de Atencion Social': 'Centros de Atención Social',
    'Centro de Asistencia Social': 'Centros de Atención Social'
})

# %%
# Paso 4: Tratar ubicaciones repetidas

# Redondear latitud y longitud a los primeros 5 dígitos decimales, podemos testear un poco
coord_tr['latitud_3d'] = coord_tr['latitud'].round(3).astype(str)
coord_tr['longitud_3d'] = coord_tr['longitud'].round(3).astype(str)

# %%
# Crear una nueva columna que combina los 5 primeros dígitos de latitud y longitud con la descripción
coord_tr['lat_long_desc'] = coord_tr['latitud_5d'] + coord_tr['longitud_5d'] + coord_tr['descripcion']

# %%
# Identificar duplicados según las condiciones y mantener el primer resultado de cada duplicado
coord_tr = coord_tr.drop_duplicates(subset=['lat_long_desc'], keep='first')

# Eliminar las columnas temporales que se crearon para este paso
coord_tr = coord_tr.drop(columns=['latitud_5d', 'longitud_5d', 'lat_long_desc'])

# (Opcional) Puedes resetear el índice para que sea consecutivo después de la eliminación
coord_tr = coord_tr.reset_index(drop=True)

# %%
#Hacemos validaciones con shape

coord_tr.head()
# Out:
#                                                 name  \
# 0                        DIF Estatal Baja California
# 1                              Ángeles Sin Fronteras
# 2               Centro de Apoyo al Trabajor Migrante
# 3   Centro de Apoyo al Trabajador Migrante: Comit...
# 4                                Comedor Cobina A.C.
#
#                   descripcion    latitud    longitud  \
# 0                         DIF  32.663780 -115.464355
# 1  Centros de Atención Social  32.662937 -115.494983
# 2  Centros de Atención Social  32.660848 -115.479494
# 3  Centros de Atención Social  32.660305 -115.459726
# 4  Centros de Atención Social  32.660301 -115.489875
#
#                               coordenadas       tipo  \
# 0                 32.6637802, -115.464355        GOB
# 1  32.66293697601438, -115.49498343917332  OSC / ONG
# 2  32.660847720110326, -115.4794934911816  OSC / ONG
# 3                32.6603047, -115.4597261  OSC / ONG
# ...

# %%
#Ultima Actualizacion del documento

#coord_tr.to_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/institucionesmigracionfullfinal.csv', index=False, encoding='utf-8')

# %% [markdown]
# ### Otros procesamientos adicionales:

# %%
#Hacer un dataframe sin las ubicaciones de SEMIGRANTE 

#coord_trnosem = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/institucionesmigracionfullfinal.csv', encoding='utf-8')

# %%
coord_trnosem.head()
# Out:
#                                                 name  \
# 0                        DIF Estatal Baja California
# 1                              Ángeles Sin Fronteras
# 2               Centro de Apoyo al Trabajor Migrante
# 3   Centro de Apoyo al Trabajador Migrante: Comit...
# 4                                Comedor Cobina A.C.
#
#                   descripcion    latitud    longitud  \
# 0                         DIF  32.663780 -115.464355
# 1  Centros de Atención Social  32.662937 -115.494983
# 2  Centros de Atención Social  32.660848 -115.479494
# 3  Centros de Atención Social  32.660305 -115.459726
# 4  Centros de Atención Social  32.660301 -115.489875
#
#                               coordenadas       tipo  \
# 0                 32.6637802, -115.464355        GOB
# 1  32.66293697601438, -115.49498343917332  OSC / ONG
# 2  32.660847720110326, -115.4794934911816  OSC / ONG
# 3                32.6603047, -115.4597261  OSC / ONG
# ...

# %%
coord_trnosem.shape
# Out:
# (1233, 8)

# %%
# Filtrar las filas donde la columna "descripcion" NO sea "SEMIGRANTE"
coord_trnosem_filtered = coord_trnosem[coord_trnosem['descripcion'] != 'SEMIGRANTE']

print(coord_trnosem_filtered.shape)
# Out:
# (1189, 8)

# %%
#coord_trnosem_filtered.to_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/institucionesmigracionfullprueba.csv', index=False, encoding='utf-8')

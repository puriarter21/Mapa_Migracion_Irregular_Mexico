# %% [markdown]
# # GEOCODE

# %%
import pandas as pd  # Library for data manipulation and analysis

from geopy.geocoders import Photon
from geopy.geocoders import Nominatim

# %% [markdown]
# ## Pruebas
#
# librerias:
#
#     -Photon: buenas pruebas, si agarra la mayoria de las direcciones mexicanas.
#     -Nominatim, no agarra direcciones mexicanas.

# %%
df = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Instituciones/notebooks_institucion/directorio_redes.csv')

# %%
df.head(10)

# %%
#photon
geolocator = Photon(user_agent="pablo'sthesis")
location = geolocator.geocode("José María Marroquí 83 Colonia Centro, 06000, ciudad de mexico")
print(location.address)
print((location.latitude, location.longitude))
# Out:
# Calle José María Marroquí, 06050, Ciudad de México, México
# (19.4306746, -99.1437991)

# %% [markdown]
# # Direcciones a coordenadas .csv

# %% [markdown]
# def get_lat(address):
#     geolocator = Photon(user_agent="pablosthesis", timeout=10)
#     try:
#         location = geolocator.geocode(address)
#         return location.latitude
#     except AttributeError:
#         return '', ''
#
# def get_lon(address):
#     geolocator = Photon(user_agent="pablosthesis", timeout=10)
#     try:
#         location = geolocator.geocode(address)
#         return  location.longitude
#     except AttributeError:
#         return '', ''

# %%
def get_coordinates(address):
    if pd.isnull(address): # Check if the address is NaN
        return None, None
    geolocator = Photon(user_agent="pablosthesis", timeout=10)
    try:
        location = geolocator.geocode(address)
        return location.latitude, location.longitude
    except AttributeError:
        return None, None

# %% [markdown]
# ## 1. Redes

# %%
dfredes = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Instituciones/notebooks_institucion/1.Redes.csv', encoding='utf-8')

# %%
#dfredes.head(10)

#print(dfredes.shape)

# %%
# Aplicamos la función para obtener las coordenadas
dfredes['latitud'], dfredes['longitud'] = zip(*dfredes['direccion'].apply(get_coordinates))

# Combinamos latitud y longitud en una nueva columna
dfredes['coordenadas'] = dfredes[['latitud', 'longitud']].apply(tuple, axis=1)

# %%
#para actualizar el documento.
#dfredes.to_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Instituciones/notebooks_institucion/bd_ubicaciones/1.Redesfinal.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## 2.agenciasonu.csv

# %%
#dfagencias = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/2.agenciasonu.csv', encoding='utf-8')

# %%
# Aplicamos la función para obtener las coordenadas
#dfagencias['latitud'], dfagencias['longitud'] = zip(*dfagencias['direccion'].apply(get_coordinates))

# Combinamos latitud y longitud en una nueva columna
#dfagencias['coordenadas'] = dfagencias[['latitud', 'longitud']].apply(tuple, axis=1)

# Suponiendo que df es tu DataFrame
#dfagencias["coordenadas"] = dfagencias["coordenadas"].str.strip("()")

# %%
# Suponiendo que df es tu DataFrame
#dfagencias["coordenadas"] = dfagencias["coordenadas"].str.strip("()")

# %%
#dfagencias.head(50)

# %%
#para actualizar el documento.
#dfagencias.to_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/2.agenciasonu.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## 3.ACNUR Servicios

# %% [markdown]
# ## Albergues Directorio ONU

# %%
#df7 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/7.aberguesdirecotorioonu.csv', encoding='utf-8')

# %%
# Aplicamos la función para obtener las coordenadas
#df7['latitud'], df7['longitud'] = zip(*df7['direccion'].apply(get_coordinates))

# Combinamos latitud y longitud en una nueva columna
#df7['coordenadas'] = df7[['latitud', 'longitud']].apply(tuple, axis=1)

# %%
# Suponiendo que df es tu DataFrame
#df7["coordenadas"] = df7["coordenadas"].str.strip("()")

# %%
#df7.head(50)

# %%
#para actualizar el documento.
#df7.to_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/ubi_procesadas(faltavalidacion)/7.aberguesdirecotorioonu.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Cruz Roja

# %%
#df8 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/8.cruzroja.csv', encoding='utf-8')

# %%
# en caso de que haya nans en la columna name
#df8 = df8.dropna(subset=["name"])

# %%
#df8.head(50)

# %%
# Aplicamos la función para obtener las coordenadas
#df8['latitud'], df8['longitud'] = zip(*df7['direccion'].apply(get_coordinates))

# Combinamos latitud y longitud en una nueva columna
#df8['coordenadas'] = df8[['latitud', 'longitud']].apply(tuple, axis=1)

# %%
# Suponiendo que df es tu DataFrame
#df8["coordenadas"] = df8["coordenadas"].str.strip("()")

# %%
#para actualizar el documento.
#df8.to_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/ubi_procesadas(faltavalidacion)/8.cruzroja.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## 9.centrosasistenciasocial.csv

# %%
# Cargar el archivo
df9 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/9.centrosasistenciasocial.csv', encoding='utf-8')

# Extraer las coordenadas y combinarlas
df9['latitud'], df9['longitud'] = zip(*df9['direccion'].apply(get_coordinates))
df9['coordenadas'] = df9[['latitud', 'longitud']].apply(tuple, axis=1)

# Eliminar filas con valores nulos en la columna "name"
#df9 = df9.dropna(subset=["name"])

# Guardar el archivo procesado
#df9.to_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/ubi_procesadas(faltavalidacion)/9.centrosasistenciasocial.csv', index=False, encoding='utf-8')

# %%
df9.tail(50)
# Out:
#                                                  name         descripcion  \
# 10                Casa Hogar Alegre Odres Nuevos A.C.  Albergue / Comedor
# 11                         El Faro de Esperanza A. C.  Albergue / Comedor
# 12                            Los Niños son de Cristo  Albergue / Comedor
# 13                                    México Mi Hogar  Albergue / Comedor
# 14         Albergue para Repatriados y Menor Migrante  Albergue / Comedor
# 15      Centro de Estancia de Transitoria de la PGJDF  Albergue / Comedor
# 16              Fundación Casa Alianza México, I.A.P.  Albergue / Comedor
# 17                  Fundación Dar y Amar Daya, I.A.P.  Albergue / Comedor
# 18                                Hogares Providencia  Albergue / Comedor
# 19                      Yolia Niñas de la Calle, A.C.  Albergue / Comedor
# 20    Casa de los Niños y las Niñas Sección Casa Cuna  Albergue / Comedor
# 21                 Casa de los Niños Sección Albergue  Albergue / Comedor
# ...

# %% [markdown]
# ## 10.fiscaliasmig.csv

# %%
# Cargar el archivo
df10 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/10.fiscaliasmig.csv', encoding='utf-8')

# Extraer las coordenadas y combinarlas
df10['latitud'], df10['longitud'] = zip(*df10['direccion'].apply(get_coordinates))
df10['coordenadas'] = df10[['latitud', 'longitud']].apply(tuple, axis=1)

# Eliminar filas con valores nulos en la columna "name"
#df10 = df10.dropna(subset=["name"])

# Guardar el archivo procesado
df10.to_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/ubi_procesadas(faltavalidacion)/10.fiscaliasmig.csv', index=False, encoding='utf-8')

# %%
df10.head()
# Out:
#                                                 name  \
# 0  Unidad de Investigación de Delitos para Person...
# 1  Fiscalía Especializada de Atención para Person...
# 2  Dirección General de Delitos de Alto Impacto C...
# 3  Fiscalía Especializada de Atención a Personas ...
# 4  Fiscalía Especializada de Atención a Personas ...
#
#                                          descripcion    latitud    longitud  \
# 0  FISCALÍAS ESPECIALIZADAS PARA PERSONAS MIGRAN...  19.418323  -99.162565
# 1  FISCALÍAS ESPECIALIZADAS PARA PERSONAS MIGRAN...  14.909123  -92.248675
# 2  FISCALÍAS ESPECIALIZADAS PARA PERSONAS MIGRAN...  25.647564 -102.111675
# 3  FISCALÍAS ESPECIALIZADAS PARA PERSONAS MIGRAN...        NaN         NaN
# 4  FISCALÍAS ESPECIALIZADAS PARA PERSONAS MIGRAN...        NaN         NaN
#
#                   coordenadas tipo  \
# 0   (19.4183227, -99.1625655)  GOB
# 1   (14.9091235, -92.2486749)  GOB
# 2  (25.6475636, -102.1116751)  GOB
# 3                  (nan, nan)  GOB
# ...

# %% [markdown]
# ## 11.gruposbeta.csv

# %%
# Cargar el archivo
df11 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/11.gruposbeta.csv', encoding='utf-8')

# Extraer las coordenadas y combinarlas
df11['latitud'], df11['longitud'] = zip(*df11['direccion'].apply(get_coordinates))
df11['coordenadas'] = df11[['latitud', 'longitud']].apply(tuple, axis=1)

# Eliminar filas con valores nulos en la columna "name"
#df11 = df11.dropna(subset=["name"])

# Guardar el archivo procesado
df11.to_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/ubi_procesadas(faltavalidacion)/11.gruposbeta.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## 12.instmujeres.csv

# %%
# Cargar el archivo
df12 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/12.instmujeres.csv', encoding='utf-8')

# Extraer las coordenadas y combinarlas
df12['latitud'], df12['longitud'] = zip(*df12['direccion'].apply(get_coordinates))
df12['coordenadas'] = df12[['latitud', 'longitud']].apply(tuple, axis=1)

# Eliminar filas con valores nulos en la columna "name"
#df12 = df12.dropna(subset=["name"])

# Guardar el archivo procesado
df12.to_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/ubi_procesadas(faltavalidacion)/12.instmujeres.csv', index=False, encoding='utf-8')

# %%
df12.head(10)
# Out:
#                                                 name descripcion    latitud  \
# 0           Instituto Aguascalentense de las Mujeres     Mujeres        NaN
# 1  Instituto de la Mujer para el Estado de Baja C...     Mujeres        NaN
# 2           Instituto Sudcaliforniano de las Mujeres     Mujeres  22.997192
# 3       Instituto de la Mujer del Estado de Campeche     Mujeres        NaN
# 4                          Secretaría de las Mujeres     Mujeres        NaN
# 5                 Instituto Colimense de las Mujeres     Mujeres  22.997192
# 6               Instituto Jalisciense de las Mujeres     Mujeres        NaN
# 7  Secretaría de Igualdad Sustantiva y Desarrollo...     Mujeres        NaN
# 8    Instituto de la Mujer para el Estado de Morelos     Mujeres        NaN
# 9                   Instituto para la Mujer Nayarita     Mujeres  21.515775
#
#      longitud                 coordenadas       tipo  \
# 0         NaN                  (nan, nan)  OSC / ONG
# ...

# %% [markdown]
# ## 13.inm.csv

# %%
# Cargar el archivo
df13 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/13.inm.csv', encoding='utf-8')

# Extraer las coordenadas y combinarlas
df13['latitud'], df13['longitud'] = zip(*df13['direccion'].apply(get_coordinates))
df13['coordenadas'] = df13[['latitud', 'longitud']].apply(tuple, axis=1)

# Eliminar filas con valores nulos en la columna "name"
#df13 = df13.dropna(subset=["name"])

# Guardar el archivo procesado
df13.to_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/ubi_procesadas(faltavalidacion)/13.inm.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## 14.cndh.csv

# %%
# Cargar el archivo
df14 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/14.cndh.csv', encoding='utf-8')

# Extraer las coordenadas y combinarlas
df14['latitud'], df14['longitud'] = zip(*df14['direccion'].apply(get_coordinates))
df14['coordenadas'] = df14[['latitud', 'longitud']].apply(tuple, axis=1)

# Eliminar filas con valores nulos en la columna "name"
#df14 = df14.dropna(subset=["name"])

# Guardar el archivo procesado
df14.to_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/ubi_procesadas(faltavalidacion)/14.cndh.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## 15.consulados.csv

# %%
# Cargar el archivo
#df15 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/15.consulados.csv', encoding='utf-8')

# Extraer las coordenadas y combinarlas
#df15['latitud'], df15['longitud'] = zip(*df15['direccion'].apply(get_coordinates))
#df15['coordenadas'] = df15[['latitud', 'longitud']].apply(tuple, axis=1)

# %%
# Eliminar filas con valores nulos en la columna "name"
#df15 = df15.dropna(subset=["name"])

# %%
# Guardar el archivo procesado
#df15.to_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/ubi_procesadas(faltavalidacion)/15.consulados.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## 16.oficinasdif.csv

# %%
# Cargar el archivo
#df16 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/16.oficinasdif.csv', encoding='utf-8')

# Extraer las coordenadas y combinarlas
#df16['latitud'], df16['longitud'] = zip(*df16['direccion'].apply(get_coordinates))
#df16['coordenadas'] = df16[['latitud', 'longitud']].apply(tuple, axis=1)

# %%
# Eliminar filas con valores nulos en la columna "name"
#df16 = df16.dropna(subset=["name"])

# %%
# Guardar el archivo procesado
#df16.to_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/ubi_procesadas(faltavalidacion)/16.oficinasdif.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## 17.comar

# %%
# Cargar el archivo
#df17 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/17.comar.csv', encoding='utf-8')

# Extraer las coordenadas y combinarlas
#df17['latitud'], df17['longitud'] = zip(*df17['direccion'].apply(get_coordinates))
#df17['coordenadas'] = df17[['latitud', 'longitud']].apply(tuple, axis=1)

# Eliminar filas con valores nulos en la columna "name"
#df17 = df17.dropna(subset=["name"])

# Guardar el archivo procesado
#df17.to_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/ubi_procesadas(faltavalidacion)/17.comar.csv', index=False, encoding='utf-8')

# %% [markdown]
# # Hicimos una validacion manual para revisar las coordenadas

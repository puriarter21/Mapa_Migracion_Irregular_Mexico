# %% [markdown]
# # GEOCODE

# %%
import pandas as pd  # Library for data manipulation and analysis

from geopy.geocoders import Photon
from geopy.geocoders import Nominatim

# %% [markdown]
# ## Pruebas
#
# librerias:
#
#     -Photon:, buenas pruebas, si agarra la mayoria de las direcciones mexicanas.
#     -Nominatim, no agarra direcciones mexicanas.

# %%
df = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Instituciones/notebooks_institucion/directorio_redes.csv')

# %%
df.head(10)

# %%
#subset para probar
indices_seleccionados = [2,3,4,5,6,7,8,70]
subset_df = df.iloc[indices_seleccionados]

# %%
#photon
geolocator = Photon(user_agent="pablo'sthesis")
location = geolocator.geocode("José María Marroquí 83 Colonia Centro, 06000, ciudad de mexico")
print(location.address)
print((location.latitude, location.longitude))
# Out:
# Calle José María Marroquí, 06050, Ciudad de México, México
# (19.4306746, -99.1437991)

# %%
#Nominatim
geolocator = Nominatim(user_agent="pablo'sthesis")
location = geolocator.geocode("Otros Dreams en Acción")
print(location.address)
print((location.latitude, location.longitude))

# %% [markdown]
# ## FUNCION GETLATLON
# para sacar la latitud y la longitud

# %%
#geolocatornominatim

def get_lat_lon(address):
    geolocator = Photon(user_agent="pablosthesis", timeout=10)
    try:
        location = geolocator.geocode(address)
        return location.latitude, location.longitude
    except AttributeError:
        return '', ''

# %%
df["latlon"] = df["DirecciónCompleta"].apply(get_lat_lon)

# %%
#df.head(55)

# %%
#direcciones no encontradas con Photon: 102
conteo_latlon = df["latlon"].value_counts()
conteo_latlon

# %% [markdown]
# ### Direcciones a coordenadas .csv

# %% [markdown]
# def get_lat(address):
#     geolocator = Photon(user_agent="pablosthesis", timeout=10)
#     try:
#         location = geolocator.geocode(address)
#         return location.latitude
#     except AttributeError:
#         return '', ''
#
# def get_lon(address):
#     geolocator = Photon(user_agent="pablosthesis", timeout=10)
#     try:
#         location = geolocator.geocode(address)
#         return  location.longitude
#     except AttributeError:
#         return '', ''

# %%
def get_coordinates(address):
    if pd.isnull(address): # Check if the address is NaN
        return None, None
    geolocator = Photon(user_agent="pablosthesis", timeout=10)
    try:
        location = geolocator.geocode(address)
        return location.latitude, location.longitude
    except AttributeError:
        return None, None

# %% [markdown]
# ## 1. Redes

# %%
dfredes = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Instituciones/notebooks_institucion/1.Redes.csv', encoding='utf-8')

# %%
#dfredes.head(10)

#print(dfredes.shape)

# %%
# Aplicamos la función para obtener las coordenadas
dfredes['latitud'], dfredes['longitud'] = zip(*dfredes['direccion'].apply(get_coordinates))

# Combinamos latitud y longitud en una nueva columna
dfredes['coordenadas'] = dfredes[['latitud', 'longitud']].apply(tuple, axis=1)

# %%
#para actualizar el documento.
#dfredes.to_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Instituciones/notebooks_institucion/bd_ubicaciones/1.Redesfinal.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## 2.agenciasonu.csv

# %%
dfagencias = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/2.agenciasonu.csv', encoding='utf-8')

# %%
# Aplicamos la función para obtener las coordenadas
dfagencias['latitud'], dfagencias['longitud'] = zip(*dfagencias['direccion'].apply(get_coordinates))

# Combinamos latitud y longitud en una nueva columna
dfagencias['coordenadas'] = dfagencias[['latitud', 'longitud']].apply(tuple, axis=1)

# Suponiendo que df es tu DataFrame
dfagencias["coordenadas"] = dfagencias["coordenadas"].str.strip("()")

# %%
# Suponiendo que df es tu DataFrame
dfagencias["coordenadas"] = dfagencias["coordenadas"].str.strip("()")

# %%
dfagencias.head(50)
# Out:
#                                                  name descripcion    latitud  \
# 0   Alto Comisionado de las Naciones\nUnidas para ...         ONU  19.440998
# 1                                       Banco Mundial         ONU  19.366527
# 2   Oficina para la Coordinación de Asuntos Humani...         ONU        NaN
# 3     Organización Internacional para las Migraciones         ONU  19.348524
# 4   Comisión Económica para América Latina y el Ca...         ONU  19.440256
# 5   Centro de Información de las Naciones Unidas p...         ONU        NaN
# 6   Organización de las Naciones Unidas para la Al...         ONU  19.319781
# 7                Corporación Financiera Internacional         ONU  19.424816
# 8        Organización de Aviación Civil Internacional         ONU  19.429379
# 9   Oficina del Alto Comisionado de las Naciones U...         ONU  19.433208
# 10  Oficina para la Coordinación de Asuntos Humani...         ONU        NaN
# 11    Organización Internacional para las Migraciones         ONU  19.348524
# 12             Organización Internacional del Trabajo         ONU  19.427472
# 13                 Organización Meteorológica Mundial         ONU  19.337532
# 14  Organización de las Naciones Unidas para el De...         ONU  19.430068
# 15  Programa de Naciones Unidas para los Asentamie...         ONU  19.427343
# 16                                        ONU MUJERES         ONU  19.429379
# 17                   Organización Mundial de la Salud         ONU  19.402001
# 18  Programas de las Naciones Unidas para el Desar...         ONU        NaN
# 19   Programa de las Naciones Unidas para el Ambiente         ONU  19.418249
# 20  La Organización de las Naciones Unidas para la...         ONU  19.429379
# 21          Fondo de Población de las Naciones Unidas         ONU  19.429379
# 22      Fondo de las Naciones Unidas para la Infancia         ONU  19.426153
# 23  Oficina de Naciones Unidas contra la Droga y e...         ONU  19.440256
# 24                 Voluntarios de las Naciones Unidas         ONU        NaN
#
#      longitud                             coordenadas       tipo  \
# 0  -99.196388                 19.4409983, -99.1963879  OSC / ONG
# 1  -99.185483                 19.3665269, -99.1854833  OSC / ONG
# 2         NaN                                nan, nan  OSC / ONG
# 3  -99.170507                 19.3485242, -99.1705066  OSC / ONG
# 4  -99.192632                 19.4402557, -99.1926322  OSC / ONG
# 5         NaN                                nan, nan  OSC / ONG
# 6  -99.207380                 19.3197812, -99.2073801  OSC / ONG
# 7  -99.174439  19.424816149999998, -99.17443887344135  OSC / ONG
# 8  -99.196393                 19.4293791, -99.1963927  OSC / ONG
# 9  -99.195545                 19.4332082, -99.1955454  OSC / ONG
# 10        NaN                                nan, nan  OSC / ONG
# 11 -99.170507                 19.3485242, -99.1705066  OSC / ONG
# 12 -99.177193                 19.4274716, -99.1771925  OSC / ONG
# 13 -99.189991                 19.3375325, -99.1899911  OSC / ONG
# 14 -99.231779         19.43006785, -99.23177876185858  OSC / ONG
# 15 -99.165215  19.427343450000002, -99.16521487737674  OSC / ONG
# 16 -99.196393                 19.4293791, -99.1963927  OSC / ONG
# 17 -99.238274                 19.4020009, -99.2382738  OSC / ONG
# 18        NaN                                nan, nan  OSC / ONG
# 19 -99.164755                 19.4182486, -99.1647551  OSC / ONG
# 20 -99.196393                 19.4293791, -99.1963927  OSC / ONG
# 21 -99.196393                 19.4293791, -99.1963927  OSC / ONG
# 22 -99.186628         19.42615325, -99.18662792093049  OSC / ONG
# 23 -99.192632                 19.4402557, -99.1926322  OSC / ONG
# 24        NaN                                nan, nan  OSC / ONG
#
#                                             direccion              bd
# 0   Miguel de Cervantes Saavedra 193, Piso 14,\nOf...  Directorio OIM
# 1   Insurgentes Sur 1605, Piso 24, Col. San José I...  Directorio OIM
# 2   Montes Urales 440, Piso 3, Col. Lomas de Chapu...  Directorio OIM
# 3   Francisco Sosa 267, Col. Santa Catarina Coyoac...  Directorio OIM
# 4   Miguel de Cervantes Saavedra 193, Piso 12, Col...  Directorio OIM
# 5   Montes Urales 440, Piso 3, Col. Lomas de Chapu...  Directorio OIM
# 6   Farallón 130, Col. Jardines del Pedregal, C.P....  Directorio OIM
# 7   Paseo de la Reforma 483, Torre Reforma piso 18...  Directorio OIM
# 8   Masaryk 29, Piso 3, Col. Polanco, C.P. 11570, ...  Directorio OIM
# 9   Alejandro Dumas 165, Col. Polanco, C.P.11560, ...  Directorio OIM
# 10  Montes Urales 440, Piso 3, Col. Lomas de Chapu...  Directorio OIM
# 11  Francisco Sosa 267, Col. Santa Catarina Coyoac...  Directorio OIM
# 12  Comte 35, Col. Anzures, C.P. 11590 Ciudad de M...  Directorio OIM
# 13  Edificio CONAGUA Insurgentes Sur 2416, Piso 8,...  Directorio OIM
# 14  Puente de Tecamachalco 6, Edificio Anexo - Pla...  Directorio OIM
# 15  Paseo de la Reforma 296, Col. Juárez, C.P. 066...  Directorio OIM
# 16  Homero 806, Col. Polanco, C.P. 11550, Ciudad d...  Directorio OIM
# 17  Montes Urales 440, Piso 2, Col. Lomas de Chapu...  Directorio OIM
# 18  Montes Urales 440, Piso 5, Col. Lomas de Chapu...  Directorio OIM
# 19  Edificio CONAFOR Calle de Oro 17, Col. Roma No...  Directorio OIM
# 20  Masaryk 526, Piso 3, Col. Polanco, C.P. 11560,...  Directorio OIM
# 21  Homero 806, Col. Polanco, C.P. 11550 Ciudad de...  Directorio OIM
# 22  Paseo de la Reforma 645, Col. Lomas de Chapult...  Directorio OIM
# 23  Miguel de Cervantes Saavedra 169, Col. Granada...  Directorio OIM
# 24  Montes Urales 440, Piso 3, Col. Lomas de Chapu...  Directorio OIM

# %%
#para actualizar el documento.
#dfagencias.to_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/2.agenciasonu.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## 3.ACNUR Servicios

# %% [markdown]
# ##

# %%
df7 = pd.read_csv('/Users/pablouriarte/Documents/1. Expediente Tec de Monterrey/1.Tesis/Mapa_Migracion_Irregular_Mexico/instituciones_prepro/7.aberguesdirecotorioonu.csv', encoding='utf-8')

# %%
df7.head()
# Out:
#                                  name         descripcion  latitud  longitud  \
# 0                           Esperanza  Albergue / Comedor      NaN       NaN
# 1                    Camino a la Vida  Albergue / Comedor      NaN       NaN
# 2  Casa de Oración del Migrante, A.C.  Albergue / Comedor      NaN       NaN
# 3               Ángeles Sin Fronteras  Albergue / Comedor      NaN       NaN
# 4                         San Vicente  Albergue / Comedor      NaN       NaN
#
#    coordenadas       tipo                                          direccion  \
# 0          NaN  OSC / ONG  3a Calle Ote. No. 37, Col. Centro jurídica Tap...
# 1          NaN  OSC / ONG  José Guadalupe Posada 828, Barrio Guadalupe (a...
# 2          NaN  OSC / ONG    Niños Héroes 981, Col. Jesús Munguia C.P. 22840
# 3          NaN  OSC / ONG       Av. Reforma 244, Altos Zona Centro C.P.21100
# 4          NaN  OSC / ONG           Calle 9a 691, Col. Bustamante C.P. 22840
#
#                bd
# 0  Directorio OIM
# 1  Directorio OIM
# 2  Directorio OIM
# 3  Directorio OIM
# 4  Directorio OIM

# %%
df7
